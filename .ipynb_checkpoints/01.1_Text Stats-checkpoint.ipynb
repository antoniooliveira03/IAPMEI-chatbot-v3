# %%
import json
from pathlib import Path
import pandas as pd

# %%
def load_json_to_dataframe(folder: str) -> pd.DataFrame:
    dfs = []

    for file in Path(folder).glob("*.json"):
        with open(file, "r", encoding="utf-8") as f:
            records = json.load(f)

        temp_df = pd.DataFrame(records)

        # Only process if Q and A are present
        if {"Q", "A"}.issubset(temp_df.columns):
            temp_df["text"] = (
                "Q: " + temp_df["Q"].fillna("") +
                "\nA: " + temp_df["A"].fillna("")
            )

            temp_df.drop(columns=["Q", "A"], inplace=True)

            if "url" not in temp_df.columns:
                # use index to make each chunk unique
                temp_df["url"] = [
                    f"placeholder_{file.stem}_{i}" for i in range(len(temp_df))
                ]

        temp_df["file"] = file.stem
        dfs.append(temp_df)

    return pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()

# %%
data_bc = load_json_to_dataframe("data/01_extracted")
data_ac = load_json_to_dataframe("data/03_chunked")

# %%
data_bc.head()
# Out:
#                                                 text                url file  \
# 0  Q: O que é o Fundo Europeu de Desenvolvimento ...   placeholder_FC_0   FC
# 1  Q: Quais são os principais objetivos do Fundo ...   placeholder_FC_1   FC
# 2  Q: Para mais Informações acerca do FEDER\nA: C...   placeholder_FC_2   FC
# 3  Q: O que é o FTJ?\nA: O Fundo para uma Transiç...  placeholder_FTJ_0  FTJ
# 4  Q: Quais são os principais objetivos do FTJ\nA...  placeholder_FTJ_1  FTJ
#
#   type  depth
# 0  NaN    NaN
# 1  NaN    NaN
# 2  NaN    NaN
# 3  NaN    NaN
# 4  NaN    NaN

# %% [markdown]
# Word count per line

# %%
data_bc['word_count'] = data_bc["text"].str.split().str.len()
data_ac['word_count'] = data_ac["content"].str.split().str.len()

# %% [markdown]
# **URLs**

# %%
data_bc["url"].nunique()
# Out:
# 835

# %%
data_ac["url"].nunique()
# Out:
# 815

# %% [markdown]
# **Statistics**

# %%
data_ac['file'].unique()
# Out:
# array(['FC', 'FTJ', 'algarve_portugal2030', 'FEDER', 'centro2030', 'IGFV',
#        'portugal2030', 'iapmei_website', 'iapmei',
#        'alentejo_portugal2030', 'FAMI', 'norte2030', 'FEAMPA', 'FSI',
#        'FSE', 'compete2030', 'lisboa_portugal2030'], dtype=object)

# %%
def summarize_text_stats(df, text_col="text", file_col="file", page_col="url"):
    """
    Generate summary statistics for a text dataset.

    """

    # Aggregate at page level to normalize chunking
    page_stats = df.groupby([file_col, page_col]).agg(
        words_per_page=('word_count', 'sum'),
        chunks_per_page=('word_count', 'count')  
    ).reset_index()
    
    # Summary per file
    summary = page_stats.groupby(file_col).agg(
        total_pages=(page_col, 'count'),          # number of original pages
        total_words=('words_per_page', 'sum'),    # sum of all words
        avg_words=('words_per_page', 'mean'),     # avg words per page
        std_words=('words_per_page', 'std'),      # std dev per page
        avg_chunks_per_page=('chunks_per_page', 'mean')  # avg chunks per page (optional)
    ).reset_index()
    
    # Overall stats
    overall = pd.DataFrame({
        file_col: ['Overall'],
        'total_pages': [summary['total_pages'].sum()],
        'total_words': [summary['total_words'].sum()],
        'avg_words': [page_stats['words_per_page'].mean()],
        'std_words': [page_stats['words_per_page'].std()],
        'avg_chunks_per_page': [page_stats['chunks_per_page'].mean()]
    })
    
    summary_df = pd.concat([summary, overall], ignore_index=True)
    
    return summary_df

# %%
before = summarize_text_stats(data_bc)
before
# Out:
#                      file  total_pages  total_words     avg_words  \
# 0                    FAMI            3          171     57.000000
# 1                      FC            3          295     98.333333
# 2                  FEAMPA            3          148     49.333333
# 3                   FEDER            3          167     55.666667
# 4                     FSE            3          323    107.666667
# 5                     FSI            3          157     52.333333
# 6                     FTJ            3          308    102.666667
# 7                    IGFV            3          148     49.333333
# 8   alentejo_portugal2030           28        14534    519.071429
# 9    algarve_portugal2030           56        28380    506.785714
# 10             centro2030           30        14643    488.100000
# 11            compete2030          241       187141    776.518672
# 12                 iapmei            2          217    108.500000
# 13         iapmei_website            2       115107  57553.500000
# 14    lisboa_portugal2030           70        51902    741.457143
# 15              norte2030           47        52919   1125.936170
# 16           portugal2030          361       202215    560.152355
# 17                Overall          861       668775    776.742160
#
#        std_words  avg_chunks_per_page
# 0      41.581246             1.000000
# 1     101.362386             1.000000
# 2      34.297716             1.000000
# 3      46.003623             1.000000
# 4      85.231059             1.000000
# 5      38.423083             1.000000
# 6      93.001792             1.000000
# 7      40.550380             1.000000
# 8     270.932126             1.000000
# 9     508.807830             1.000000
# 10    309.973564             1.033333
# 11    383.665078             1.000000
# 12     88.388348             1.000000
# 13  78843.113209            31.000000
# 14    538.932700             1.014286
# 15   1671.923696             1.000000
# 16   1355.198770             1.002770
# 17   3972.532549             1.073171

# %%
after = summarize_text_stats(data_ac)
after

# %%
from collections import Counter
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('portuguese'))  # adapt if your text is in another language
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoniooliveira/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def get_most_common_words(df, text_col="text", file_col=None, top_n=100, remove_stopwords=True):
    def process_text(text):
        words = re.findall(r'\b\w+\b', str(text).lower())
        if remove_stopwords:
            words = [w for w in words if w not in stop_words]
        return words
    
    if file_col:
        result = {}
        for f, group in df.groupby(file_col):
            all_words = []
            for text in group[text_col]:
                all_words.extend(process_text(text))
            result[f] = Counter(all_words).most_common(top_n)
        return result
    else:
        all_words = []
        for text in df[text_col]:
            all_words.extend(process_text(text))
        return Counter(all_words).most_common(top_n)

# %%
common_words_bc = get_most_common_words(data_bc)

# %%
common_words_ac = get_most_common_words(data_ac, text_col="content")

# %%
from wordcloud import WordCloud

freq_dict_bc = dict(common_words_bc)
freq_dict_ac = dict(common_words_ac)

# %%
freq_dict_ac
# Out:
# {'2030': 4713,
#  'portugal': 2793,
#  '2025': 2348,
#  'inovação': 1594,
#  '1': 1568,
#  'avisos': 1396,
#  'aviso': 1394,
#  'programa': 1323,
#  'fundos': 1291,
#  'notícias': 1256,
#  '3': 1111,
#  'desenvolvimento': 978,
#  'empresas': 954,
#  'alentejo': 953,
#  'compete': 941,
#  'apoio': 886,
#  'projeto': 866,
#  'entidades': 844,
#  '2024': 843,
#  '2': 839,
#  'algarve': 828,
#  'pode': 806,
#  'ajuda': 796,
#  'dezembro': 796,
#  'norte': 779,
#  'projetos': 777,
#  'resultados': 775,
#  'objetivo': 768,
#  'europeus': 754,
#  'centro': 754,
#  'i': 747,
#  'eventos': 745,
#  '4': 733,
#  'programas': 729,
#  'legislação': 728,
#  '2023': 726,
#  'região': 713,
#  'º': 681,
#  'sobre': 652,
#  'social': 646,
#  'documentação': 645,
#  'comunicação': 633,
#  'digital': 627,
#  'política': 626,
#  'tipologia': 602,
#  'plano': 599,
#  'recursos': 598,
#  'investimento': 598,
#  'regional': 592,
#  'tipo': 589,
#  '01': 588,
#  'candidaturas': 581,
#  'operação': 576,
#  'europeia': 551,
#  'territorial': 549,
#  'gestão': 542,
#  'específico': 533,
#  'sistema': 525,
#  '2026': 523,
#  'âmbito': 520,
#  'ficha': 514,
#  'entidade': 506,
#  '30': 506,
#  'data': 504,
#  'nacional': 486,
#  'úteis': 485,
#  'dados': 483,
#  'empresarial': 479,
#  'consultar': 478,
#  'início': 473,
#  'euros': 471,
#  'transição': 465,
#  'investigação': 464,
#  'valor': 464,
#  'aqui': 461,
#  'através': 460,
#  'competitividade': 455,
#  '2020': 455,
#  'ação': 451,
#  'lisboa': 451,
#  'd': 446,
#  'promotor': 444,
#  'operações': 442,
#  'feder': 439,
#  'regiões': 438,
#  'contactos': 438,
#  'anual': 438,
#  'setembro': 436,
#  'milhões': 434,
#  'formação': 433,
#  'concurso': 426,
#  'economia': 422,
#  'podem': 421,
#  '12': 419,
#  'saúde': 418,
#  'sustentabilidade': 416,
#  'europa': 413,
#  'sustentável': 408,
#  'onde': 403,
#  'pessoas': 402}

# %%
freq_dict_bc
# Out:
# {'2030': 16251,
#  'portugal': 6373,
#  'false': 4692,
#  '00': 4292,
#  'avisos': 3602,
#  'style': 3179,
#  'notícias': 3151,
#  'p': 2971,
#  'atilde': 2923,
#  '2025': 2847,
#  'ccedil': 2825,
#  'nbsp': 2700,
#  'li': 2622,
#  'null': 2617,
#  'compete': 2571,
#  'data': 2564,
#  'follow': 2548,
#  '01': 2311,
#  '1': 2225,
#  'ajuda': 2169,
#  'fundos': 2105,
#  'eventos': 2068,
#  'programas': 2066,
#  '3': 2059,
#  'aviso': 1965,
#  'norte': 1907,
#  'id': 1905,
#  'entidade': 1887,
#  'inovação': 1857,
#  'ordem': 1855,
#  'visivel': 1837,
#  'align': 1788,
#  'text': 1778,
#  'alentejo': 1705,
#  'grupo': 1695,
#  'descricao': 1695,
#  'política': 1664,
#  'span': 1642,
#  'anexos': 1642,
#  'textfield': 1640,
#  'selectlist': 1640,
#  'checkbox': 1640,
#  'editor': 1640,
#  'tipocampo': 1640,
#  'impressao': 1640,
#  'programa': 1597,
#  'comunicação': 1538,
#  'algarve': 1529,
#  'justify': 1527,
#  '0001': 1487,
#  '01t00': 1459,
#  'contactos': 1448,
#  'centro': 1438,
#  'recursos': 1427,
#  'lisboa': 1411,
#  'projetos': 1392,
#  'site': 1357,
#  'legislação': 1347,
#  'entidades': 1331,
#  'plano': 1327,
#  'empresas': 1318,
#  'condições': 1296,
#  'conteúdo': 1256,
#  'notificações': 1246,
#  'termos': 1230,
#  'privacidade': 1229,
#  'eletrónicas': 1210,
#  'apoio': 1190,
#  '4': 1189,
#  'desenvolvimento': 1173,
#  'anual': 1167,
#  'candidaturas': 1157,
#  'color': 1154,
#  'n': 1150,
#  'dados': 1145,
#  'dezembro': 1141,
#  '2': 1087,
#  'empresa': 1087,
#  'pt': 1085,
#  'tipo': 1082,
#  'projeto': 1070,
#  'minutos': 1062,
#  '7': 1059,
#  'registo': 1058,
#  'investimento': 1056,
#  '2023': 1047,
#  'black': 1045,
#  'modo': 998,
#  'resultados': 994,
#  'pessoas': 991,
#  'sustentável': 989,
#  'balcão': 983,
#  'madeira': 982,
#  'pesquisa': 982,
#  '5': 976,
#  'operações': 974,
#  'operação': 964,
#  '2024': 962,
#  'úteis': 958,
#  'permitir': 946}

# %%
wc = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='Greens'
).generate_from_frequencies(freq_dict_bc)

# plot
plt.figure(figsize=(15, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='Greens'
).generate_from_frequencies(freq_dict_ac)

# plot
plt.figure(figsize=(15, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_most_common_words(common_words, title="Most Common Words"):

    words, counts = zip(*common_words)
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(words), y=list(counts))
    plt.xlabel("Frequency")
    plt.ylabel("Word")
    plt.title(title)
    plt.xticks(rotation=45) 
    plt.show()

# %%
plot_most_common_words(common_words_bc)

# %%
plot_most_common_words(common_words_ac)

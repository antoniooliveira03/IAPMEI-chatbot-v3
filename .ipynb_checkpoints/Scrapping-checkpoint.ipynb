# %%
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

BASE = "https://financiamento.iapmei.pt"
API_PATTERN = re.compile(r"/webapi/api/[a-zA-Z0-9_/-]+")

html = requests.get(BASE).text
soup = BeautifulSoup(html, "html.parser")

js_files = [
    urljoin(BASE, s["src"])
    for s in soup.find_all("script", src=True)
]

endpoints = set()

for js in js_files:
    try:
        code = requests.get(js, timeout=10).text
        matches = API_PATTERN.findall(code)
        endpoints.update(matches)
    except Exception:
        pass

for e in sorted(endpoints):
    print(e)

# %%
endpoints = await capture_endpoints()
for e in endpoints:
    print(e)
# Out:
# https://financiamento.iapmei.pt/webapi/api/ItensPesquisas?caraterizacao=2
# https://financiamento.iapmei.pt/webapi/api/Paginas/Footer
# https://financiamento.iapmei.pt/webapi/api/indicadores
# https://financiamento.iapmei.pt/webapi/api/ItensPesquisas/arrayvalores
# https://financiamento.iapmei.pt/webapi/api/paginas
# https://financiamento.iapmei.pt/webapi/api/sliders
# https://financiamento.iapmei.pt/webapi/api/ItensPesquisas
# https://financiamento.iapmei.pt/webapi/api/ItensPesquisas?caraterizacao=1
# https://financiamento.iapmei.pt/webapi/api/Itens/arrayvalores
# https://financiamento.iapmei.pt/webapi/api/Configuracao/GetRedesSociais

# %%
import asyncio
from playwright.async_api import async_playwright
import requests
from bs4 import BeautifulSoup
import json
from pathlib import Path

OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)

BASE_URL = "https://financiamento.iapmei.pt/webapi/api"

# ------------------------------
# Helper functions
# ------------------------------
def clean_html(html_str):
    if not html_str:
        return ""
    return BeautifulSoup(html_str, "html.parser").get_text(separator="\n", strip=True)

def fetch_json(url, params=None):
    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    return r.json()

def extract_text_from_data(data):
    texts = []

    if isinstance(data, dict):
        for key in ["titulo", "descricao", "conteudo", "texto"]:
            val = data.get(key)
            if isinstance(val, str) and val.strip():
                texts.append(clean_html(val))

        # Rich text components
        for comp in data.get("componentes", []):
            if isinstance(comp, dict):
                for v in comp.values():
                    if isinstance(v, str) and len(v.strip()) > 50:
                        texts.append(clean_html(v))

    elif isinstance(data, list):
        for el in data:
            if isinstance(el, dict):
                for v in el.values():
                    if isinstance(v, str) and len(v.strip()) > 50:
                        texts.append(clean_html(v))
            elif isinstance(el, str) and el.strip():
                texts.append(clean_html(el))

    return "\n".join(texts)

# ------------------------------
# Step 1: Capture endpoints via Playwright
# ------------------------------
async def capture_endpoints():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)  # set True to hide browser
        page = await browser.new_page()
        endpoints = set()

        # Capture all API responses
        page.on("response", lambda res: endpoints.add(res.url) if "/webapi/api/" in res.url else None)

        # Open homepage
        await page.goto("https://financiamento.iapmei.pt/inicio/home", wait_until="domcontentloaded")

        # Trigger lazy-loaded content
        await page.wait_for_timeout(3000)
        await page.mouse.wheel(0, 3000)
        await page.wait_for_timeout(3000)

        await browser.close()
        return endpoints

# ------------------------------
# Step 2: Fetch content from discovered endpoints
# ------------------------------
async def main():
    endpoints = await capture_endpoints()
    print(f"Discovered {len(endpoints)} API endpoints")
    
    dataset = []

    # Filter relevant endpoints: only Itens / Paginas / ItensPesquisas
    relevant = [e for e in endpoints if any(x in e.lower() for x in ["/produtos", "/paginas"])]
    print(f"Processing {len(relevant)} relevant endpoints")

    for url in relevant:
        try:
            data = fetch_json(url)
            text = extract_text_from_data(data)

            dataset.append({
                "url": url,
                "text": text
            })
            print(f"Fetched {url} → {len(text)} chars")

        except Exception as e:
            print(f"Error fetching {url}: {e}")

    # Save final dataset
    output_file = OUTPUT_DIR / "financiamento_complete.json"
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(dataset, f, ensure_ascii=False, indent=2)

    print(f"All content saved to {output_file}")
    print(f"Total documents: {len(dataset)}")

# ------------------------------
# Run
# ------------------------------
import nest_asyncio
nest_asyncio.apply()

import asyncio

# Instead of asyncio.run(main()), do:
await main()
# Out:
# Discovered 10 API endpoints
# Processing 2 relevant endpoints
# Fetched https://financiamento.iapmei.pt/webapi/api/Paginas/Footer → 7578 chars
# Fetched https://financiamento.iapmei.pt/webapi/api/paginas → 11209 chars
# All content saved to data/financiamento_complete.json
# Total documents: 2

# %%
import asyncio
import json
from urllib.parse import urljoin
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup

# =====================
# CONFIG (minimal)
# =====================
START_URL = "https://financiamento.iapmei.pt/inicio/home"
BASE_SITE = "https://financiamento.iapmei.pt"
API_PREFIX = "/webapi/api"

MAX_PAGES = 30   # safety limit

# =====================
def clean_html(text):
    return BeautifulSoup(text, "html.parser").get_text(
        separator="\n", strip=True
    )

# =====================
async def crawl_visible_pages():
    results = []
    visited = set()

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        page = await context.new_page()

        # ---- STEP 1: open homepage
        await page.goto(START_URL, wait_until="networkidle")

        await page.mouse.wheel(0, 5000)
        await page.wait_for_timeout(3000)

        # ---- STEP 2: collect visible links
        anchors = await page.query_selector_all("a")
        links = []

        for a in anchors:
            if not await a.is_visible():
                continue

            text = (await a.inner_text()).strip()
            href = await a.get_attribute("href")

            if not text or not href:
                continue

            full_url = urljoin(BASE_SITE, href)
            links.append((full_url, text))

        print(f"Found {len(links)} visible links")

        # ---- STEP 3: visit each link and capture API content
        for url, link_text in links[:MAX_PAGES]:
            if url in visited:
                continue
            visited.add(url)
        
            api_payloads = []  # reset per page
        
            def on_response(res):
                if API_PREFIX in res.url and res.request.method == "GET":
                    api_payloads.append(res)
        
            page.on("response", on_response)
        
            await page.goto(url, wait_until="networkidle")
            await page.wait_for_timeout(3000)
        
            texts = []
            for res in api_payloads:
                try:
                    data = await res.json()
                    texts.append(clean_html(json.dumps(data)))
                except:
                    pass
        
            results.append({
                "page_url": url,
                "link_text": link_text,
                "content": "\n".join(texts)
            })
        
            api_payloads.clear()  # ready for next page
        

        await browser.close()

    return results

# =====================
# RUN
# =====================
import nest_asyncio
nest_asyncio.apply()

data = await crawl_visible_pages()

print(f"\nExtracted {len(data)} pages\n")
for d in data:
    print(d["page_url"])
# Out:
# Found 13 visible links
#
# Extracted 7 pages
#
# https://financiamento.iapmei.pt#resultados
# https://financiamento.iapmei.pt/home/financiamento?id=3bc6afb6-87bc-443b-9019-683f56f7a78e
# https://financiamento.iapmei.pt/home/financiamento?id=6d430c26-fdf4-4c6a-acf8-166ea496404a
# https://financiamento.iapmei.pt/home/financiamento?id=78009eb4-5c1d-41b3-8534-221895b99ab9
# https://financiamento.iapmei.pt/home/financiamento?id=27395855-c653-47c5-9cc2-63483f6d717d
# https://financiamento.iapmei.pt/home/financiamento?id=45990c62-0b36-43a7-9029-907412aef549
# https://financiamento.iapmei.pt/inicio/home/financiamento?id=3bc6afb6-87bc-443b-9019-683f56f7a78e

# %%
import requests

urls = [
    "https://financiamento.iapmei.pt/webapi/api/paginas",
    "https://financiamento.iapmei.pt/webapi/api/produtos"
]

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json",
}

def fetch_all() -> dict:
    results = {}

    for url in urls:
        r = requests.get(url, headers=headers, timeout=10)
        r.raise_for_status()
        results[url] = r.json()

    return results


data = fetch_all()

# %%
for i in data["https://financiamento.iapmei.pt/webapi/api/paginas"]:
    print(i["titulo"], i["corpo"])
# Out:
# Linhas de Crédito <p>As linhas de cr&eacute;dito bonificadas e garantidas t&ecirc;m como objetivo melhorar as condi&ccedil;&otilde;es de financiamento e facilitar o acesso das PME ao cr&eacute;dito banc&aacute;rio, atrav&eacute;s do recurso aos mecanismos de garantia do Sistema Nacional de Garantia M&uacute;tua.</p>
#
# Garantia Mútua <p>A Garantia M&uacute;tua &eacute; um sistema mutualista de apoio &agrave;s micro, pequenas e m&eacute;dias empresas, que se traduz fundamentalmente na presta&ccedil;&atilde;o de garantias para facilitar a obten&ccedil;&atilde;o de cr&eacute;dito mas tamb&eacute;m de outro tipo de garantias necess&aacute;rias ao desenvolvimento empresarial nos v&aacute;rios setores de atividade.<br />
# <br />
# A caracter&iacute;stica mutualista resulta do facto de as empresas benefici&aacute;rias das garantias assumirem a condi&ccedil;&atilde;o de acionistas de Sociedades de Garantia M&uacute;tua.<br />
# <br />
# O sistema de garantia m&uacute;tua &eacute; participado pelo IAPMEI e por outras entidades financeiras e associativas e tem a supervis&atilde;o do Banco de Portugal.</p>
#
# <p><br />
# <strong>Modelo de atua&ccedil;&atilde;o<br />
# &nbsp;</strong><br />
# O Sistema Nacional de Garantia M&uacute;tua assenta em tr&ecirc;s pilares:</p>
#
# <p>Quatro Sociedades de Garantia M&uacute;tua (SGM), que prestam garantias em favor das Pequenas ou M&eacute;dias Empresas (PME) ou entidades representativas destas. As quatro Sociedades de Garantia M&uacute;tua existentes em Portugal s&atilde;o, a Norgarante, a Lisgarante, a Garval e a Agrogarante.</p>
#
# <p>O Fundo de Contragarantia M&uacute;tuo (FCGM), que &eacute; um fundo de &ldquo;resseguro&rdquo;, dotado com fundos p&uacute;blicos, que cobre parcialmente o risco das opera&ccedil;&otilde;es concretizadas pelas SGM, alavancando a sua capacidade de apoio &agrave;s PME.&nbsp;</p>
#
# <p>Uma entidade &ldquo;coordenadora&rdquo; de todo o sistema, que gere o FCGM e promove quer o desenvolvimento das SGM, quer a imagem do produto garantia m&uacute;tua em favor das PME, ao mesmo tempo presta servi&ccedil;os de backoffice &agrave;s entidades do sistema. Essa entidade &eacute; a SPGM &ndash; Sociedade de Investimento, que funciona na pr&aacute;tica como &ldquo;holding&rdquo; do sistema.</p>
#
# <p><br />
# <strong>Garantias</strong></p>
#
# <p>As Sociedades de Garantia M&uacute;tua est&atilde;o habilitadas a prestar &agrave;s PME todo o tipo de garantias a favor de Institui&ccedil;&otilde;es Financeiras e N&atilde;o Financeiras necess&aacute;rias &agrave; concretiza&ccedil;&atilde;o dos seus projetos, nomeadamente:</p>
#
# <p><br />
# Garantias a favor de institui&ccedil;&otilde;es financeiras</p>
#
# <p>Financiamento de Curto Prazo;<br />
# Financiamento de M&eacute;dio e de Longo Prazo;<br />
# Leasing imobili&aacute;rio e mobili&aacute;rio;<br />
# Factoring e Confirming;<br />
# Outras opera&ccedil;&otilde;es especiais de cr&eacute;dito (empr&eacute;stimos obrigacionistas, opera&ccedil;&otilde;es de papel comercial);<br />
# Garantias de Carteira<br />
# Garantias a favor de institui&ccedil;&otilde;es n&atilde;o financeiras<br />
# Garantias T&eacute;cnicas ou de Boa Execu&ccedil;&atilde;o de contratos a apresentar perante organismos p&uacute;blicos, clientes, fornecedores, etc.,<br />
# Garantias de Bom Pagamento (Fornecedores, Estado,&hellip;)</p>
#
# <ul>
# </ul>
#
# Seguros de Crédito <p>O seguro de cr&eacute;ditos protege as empresas contra o n&atilde;o pagamento de uma d&iacute;vida comercial. Ou seja, assegura que as facturas ser&atilde;o pagas e permite &agrave;s empresas gerirem de forma fi&aacute;vel os riscos comerciais e pol&iacute;ticos do com&eacute;rcio, que est&atilde;o al&eacute;m do seu controlo, como no caso de uma exporta&ccedil;&atilde;o. Assim, o capital &eacute; protegido, os fluxos de caixa s&atilde;o mantidos, a obten&ccedil;&atilde;o de empr&eacute;stimos e pagamentos &eacute; potenciada, e os ganhos ficam a salvo.</p>
#
# <p>As empresas podem recorrer a qualquer uma seguradoras privadas a operar em Portugal para efeitos de acesso ao Seguro de Cr&eacute;ditos.</p>
#
# <p style="text-align: justify;">Os&nbsp;Seguros de Cr&eacute;ditos com Garantia do Estado t&ecirc;m apenas um operador,&nbsp;por conta e ordem do Estado Portugu&ecirc;s, que &eacute;&nbsp;COSEC - Companhia de Seguros de Cr&eacute;dito, SA</p>
#
# <p>O Seguro de Cr&eacute;ditos &agrave; Exporta&ccedil;&atilde;o com Garantia do Estado cobre, em opera&ccedil;&atilde;o individualizada de exporta&ccedil;&atilde;o de bens ou servi&ccedil;os, o incumprimento do importador p&uacute;blico ou privado, causado por factos de natureza pol&iacute;tica, monet&aacute;ria e catastr&oacute;fica, podendo incluir tamb&eacute;m o risco comercial.</p>
#
# 	<li style="text-align: justify;"><span style="background-color:white"><span style="color:#555555">O&nbsp;</span></span><strong>SIFIDE - Sistema de Incentivos Fiscais &agrave; Investiga&ccedil;&atilde;o e ao Desenvolvimento Empresarial</strong>&nbsp;visa aumentar a competitividade das empresas, apoiando o seu esfor&ccedil;o em I&amp;D atrav&eacute;s da dedu&ccedil;&atilde;o &agrave; coleta do IRC das respetivas despesas.</li>
# 	<li style="text-align: justify;"><span style="color:#524f4f">Benef&iacute;cios Fiscais Aplic&aacute;veis aos<strong> Territ&oacute;rios do Interior e &agrave;s Regi&otilde;es Aut&oacute;nomas</strong></span></li>
# 	<li style="text-align: justify;"><strong><span style="color:#524f4f">A&nbsp;</span></strong><strong><span style="background-color:white"><span style="color:#555555">DLRR - Dedu&ccedil;&atilde;o por Lucros Retidos e Reinvestidos</span></span></strong><span style="background-color:white"><span style="color:#555555">&nbsp;&eacute; um regime que permite a dedu&ccedil;&atilde;o por lucros retidos e reinvestidos. Traduz-se numa medida de incentivo &agrave;s PME que permite a dedu&ccedil;&atilde;o &agrave; coleta do IRC dos lucros retidos que sejam reinvestidos, em aplica&ccedil;&otilde;es relevantes.</span></span></li>
# 	<li style="text-align: justify;"><strong><span style="color:#524f4f">Remunera&ccedil;&atilde;o Convencional do Capital Social IRC, </span></strong>&eacute; um benef&iacute;cio fiscal que tem como principal finalidade refor&ccedil;ar os capitais pr&oacute;prios das empresas e que consiste na dedu&ccedil;&atilde;o ao lucro tribut&aacute;vel de uma parte das entradas de capital realizadas (por entregas em dinheiro ou por convers&atilde;o de suprimentos ou empr&eacute;stimos de s&oacute;cios), seja no capital inicial ou seus aumentos.</li>
# </ul>

# %%
data["https://financiamento.iapmei.pt/webapi/api/paginas"]
# Out:
# [{'id': '30045a7f-f5c3-4da8-823c-f85173dce675',
#   'titulo': 'Linhas de Crédito',
#   'resumo': '(Imagem)',
#   'subtitulo': None,
#   'corpo': '<p>As linhas de cr&eacute;dito bonificadas e garantidas t&ecirc;m como objetivo melhorar as condi&ccedil;&otilde;es de financiamento e facilitar o acesso das PME ao cr&eacute;dito banc&aacute;rio, atrav&eacute;s do recurso aos mecanismos de garantia do Sistema Nacional de Garantia M&uacute;tua.</p>\r\n',
#   'pai': None,
#   'resulta': '',
#   'ultimaactualizacao': '2019-08-01',
#   'ordem': 2000},
#  {'id': 'c6df6166-2c4a-4894-9801-786d8587e2aa',
#   'titulo': 'Garantia Mútua',
#   'resumo': '(Imagem)\r\n',
#   'subtitulo': None,
#   'corpo': '<p>A Garantia M&uacute;tua &eacute; um sistema mutualista de apoio &agrave;s micro, pequenas e m&eacute;dias empresas, que se traduz fundamentalmente na presta&ccedil;&atilde;o de garantias para facilitar a obten&ccedil;&atilde;o de cr&eacute;dito mas tamb&eacute;m de outro tipo de garantias necess&aacute;rias ao desenvolvimento empresarial nos v&aacute;rios setores de atividade.<br />\r\n<br />\r\nA caracter&iacute;stica mutualista resulta do facto de as empresas benefici&aacute;rias das garantias assumirem a condi&ccedil;&atilde;o de acionistas de Sociedades de Garantia M&uacute;tua.<br />\r\n<br />\r\nO sistema de garantia m&uacute;tua &eacute; participado pelo IAPMEI e por outras entidades financeiras e associativas e tem a supervis&atilde;o do Banco de Portugal.</p>\r\n\r\n<p><br />\r\n<strong>Modelo de atua&ccedil;&atilde;o<br />\r\n&nbsp;</strong><br />\r\nO Sistema Nacional de Garantia M&uacute;tua assenta em tr&ecirc;s pilares:</p>\r\n\r\n<p>Quatro Sociedades de Garantia M&uacute;tua (SGM), que prestam garantias em favor das Pequenas ou M&eacute;dias Empresas (PME) ou entidades representativas destas. As quatro Sociedades de Garantia M&uacute;tua existentes em Portugal s&atilde;o, a Norgarante, a Lisgarante, a Garval e a Agrogarante.</p>\r\n\r\n<p>O Fundo de Contragarantia M&uacute;tuo (FCGM), que &eacute; um fundo de &ldquo;resseguro&rdquo;, dotado com fundos p&uacute;blicos, que cobre parcialmente o risco das opera&ccedil;&otilde;es concretizadas pelas SGM, alavancando a sua capacidade de apoio &agrave;s PME.&nbsp;</p>\r\n\r\n<p>Uma entidade &ldquo;coordenadora&rdquo; de todo o sistema, que gere o FCGM e promove quer o desenvolvimento das SGM, quer a imagem do produto garantia m&uacute;tua em favor das PME, ao mesmo tempo presta servi&ccedil;os de backoffice &agrave;s entidades do sistema. Essa entidade &eacute; a SPGM &ndash; Sociedade de Investimento, que funciona na pr&aacute;tica como &ldquo;holding&rdquo; do sistema.</p>\r\n\r\n<p><br />\r\n<strong>Garantias</strong></p>\r\n\r\n<p>As Sociedades de Garantia M&uacute;tua est&atilde;o habilitadas a prestar &agrave;s PME todo o tipo de garantias a favor de Institui&ccedil;&otilde;es Financeiras e N&atilde;o Financeiras necess&aacute;rias &agrave; concretiza&ccedil;&atilde;o dos seus projetos, nomeadamente:</p>\r\n\r\n<p><br />\r\nGarantias a favor de institui&ccedil;&otilde;es financeiras</p>\r\n\r\n<p>Financiamento de Curto Prazo;<br />\r\nFinanciamento de M&eacute;dio e de Longo Prazo;<br />\r\nLeasing imobili&aacute;rio e mobili&aacute;rio;<br />\r\nFactoring e Confirming;<br />\r\nOutras opera&ccedil;&otilde;es especiais de cr&eacute;dito (empr&eacute;stimos obrigacionistas, opera&ccedil;&otilde;es de papel comercial);<br />\r\nGarantias de Carteira<br />\r\nGarantias a favor de institui&ccedil;&otilde;es n&atilde;o financeiras<br />\r\nGarantias T&eacute;cnicas ou de Boa Execu&ccedil;&atilde;o de contratos a apresentar perante organismos p&uacute;blicos, clientes, fornecedores, etc.,<br />\r\nGarantias de Bom Pagamento (Fornecedores, Estado,&hellip;)</p>\r\n\r\n<ul>\r\n</ul>\r\n',
#   'pai': None,
#   'resulta': '',
#   'ultimaactualizacao': '2019-08-01',
#   'ordem': 2001},
#  {'id': '11afbac6-6b2a-4233-bef6-3d666eb6af86',
#   'titulo': 'Seguros de Crédito',
#   'resumo': '(Imagem)',
#   'subtitulo': None,
#   'corpo': '<p>O seguro de cr&eacute;ditos protege as empresas contra o n&atilde;o pagamento de uma d&iacute;vida comercial. Ou seja, assegura que as facturas ser&atilde;o pagas e permite &agrave;s empresas gerirem de forma fi&aacute;vel os riscos comerciais e pol&iacute;ticos do com&eacute;rcio, que est&atilde;o al&eacute;m do seu controlo, como no caso de uma exporta&ccedil;&atilde;o. Assim, o capital &eacute; protegido, os fluxos de caixa s&atilde;o mantidos, a obten&ccedil;&atilde;o de empr&eacute;stimos e pagamentos &eacute; potenciada, e os ganhos ficam a salvo.</p>\r\n\r\n<p>As empresas podem recorrer a qualquer uma seguradoras privadas a operar em Portugal para efeitos de acesso ao Seguro de Cr&eacute;ditos.</p>\r\n\r\n<p style="text-align: justify;">Os&nbsp;Seguros de Cr&eacute;ditos com Garantia do Estado t&ecirc;m apenas um operador,&nbsp;por conta e ordem do Estado Portugu&ecirc;s, que &eacute;&nbsp;COSEC - Companhia de Seguros de Cr&eacute;dito, SA</p>\r\n\r\n<p>O Seguro de Cr&eacute;ditos &agrave; Exporta&ccedil;&atilde;o com Garantia do Estado cobre, em opera&ccedil;&atilde;o individualizada de exporta&ccedil;&atilde;o de bens ou servi&ccedil;os, o incumprimento do importador p&uacute;blico ou privado, causado por factos de natureza pol&iacute;tica, monet&aacute;ria e catastr&oacute;fica, podendo incluir tamb&eacute;m o risco comercial.</p>\r\n',
#   'pai': None,
#   'resulta': '',
#   'ultimaactualizacao': '2019-08-01',
#   'ordem': 2002},
#  {'id': 'e1707187-da6b-4964-8187-ca8a6bfb9c51',
#   'titulo': 'Capital de Risco',
#   'resumo': '(Imagem)',
#   'subtitulo': None,
#   'corpo': '<p>O Capital de Risco constitui uma forma de financiamento para as PME, atrav&eacute;s do recurso a capitais pr&oacute;prios, por um per&iacute;odo tempor&aacute;rio.<br />\r\n<br />\r\nProporcionando &agrave;s empresas meios financeiros est&aacute;veis para a gest&atilde;o dos seus planos de desenvolvimento, este instrumento &eacute; aplic&aacute;vel a projetos de arranque, expans&atilde;o, moderniza&ccedil;&atilde;o e inova&ccedil;&atilde;o empresarial com dimens&atilde;o estrat&eacute;gica.<br />\r\n<br />\r\nO IAPMEI &eacute; o principal financiador p&uacute;blico de fundos de Capital de Risco e promove a constitui&ccedil;&atilde;o destes instrumentos em parceria com a generalidade dos operadores privados a desenvolver esta atividade.</p>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<h3><strong>Destinat&aacute;rios</strong></h3>\r\n\r\n<p>Podem beneficiar deste produto financeiro PME nacionais dos v&aacute;rios setores de atividade, que apresentem necessidades de capitais pr&oacute;prios para a implementa&ccedil;&atilde;o dos seus projetos de:</p>\r\n\r\n<ul>\r\n\t<li>cria&ccedil;&atilde;o de empresas inovadoras e de base tecnol&oacute;gica;</li>\r\n\t<li>transmiss&atilde;o e redimensionamento;</li>\r\n\t<li>expans&atilde;o, moderniza&ccedil;&atilde;o, internacionaliza&ccedil;&atilde;o e/ou diversifica&ccedil;&atilde;o.</li>\r\n</ul>\r\n\r\n<p>&nbsp;</p>\r\n\r\n<h3><strong>Funcionamento</strong></h3>\r\n\r\n<p>&nbsp;As participa&ccedil;&otilde;es no capital social das empresas atrav&eacute;s do Capital de Risco concretizam-se pela realiza&ccedil;&atilde;o de aumentos
ores privados nacionais e internacionais que demonstrem deter a experi&ecirc;ncia e qualifica&ccedil;&atilde;o para os investimentos a que se prop&otilde;e com os fundos p&uacute;blicos de <em>matching.</em></p>\r\n\r\n<p>O investimento por parte destes Fundos e pelos Coinvestidores privados &eacute; efetuado simultaneamente e nos mesmos termos e condi&ccedil;&otilde;es, pressupondo a celebra&ccedil;&atilde;o de um acordo parassocial/acordo de investimento entre a empresa destinat&aacute;ria, os Coinvestidores privados e o Fundo de Coinvestimento, que define o enquadramento relacional entre as partes. Desta forma, as empresas podem aumentar o valor de capital dispon&iacute;vel para os seus projetos, juntando ao capital privado angariado junto dos outros investidores os Fundos aqui identificados.</p>\r\n',
#   'pai': None,
#   'resulta': '',
#   'ultimaactualizacao': '2020-04-06',
#   'ordem': 2004},
#  {'id': 'befdc85f-fb21-465f-b9da-9505e36866d2',
#   'titulo': 'Fundos de Investimento Imobiliário',
#   'resumo': None,
#   'subtitulo': None,
#   'corpo': '<p style="text-align:justify">Os Fundos de Investimento Imobili&aacute;rio constituem importantes instrumentos financeiros podendo ser especialmente vocacionados para apoiar as pequenas e m&eacute;dias empresas, atrav&eacute;s de opera&ccedil;&otilde;es que consistem na aquisi&ccedil;&atilde;o e subsequente arrendamento de im&oacute;veis afetos &agrave; atividade das empresas.</p>\r\n\r\n<p style="text-align:justify">Estas opera&ccedil;&otilde;es permitem, por um lado, a separa&ccedil;&atilde;o entre a propriedade dos ativos imobili&aacute;rios e a sua gest&atilde;o e, por outro, a dota&ccedil;&atilde;o das empresas de liquidez financeira imediata.</p>\r\n',
#   'pai': None,
#   'resulta': '',
#   'ultimaactualizacao': '2019-09-05',
#   'ordem': 2005},
#  {'id': '7c407b3d-75d0-4279-ba20-3682a7d4b739',
#   'titulo': 'Benefícios Fiscais',
#   'resumo': None,
#   'subtitulo': None,
#   'corpo': '<p style="text-align: justify;"><span style="color:#524f4f">Os Benef&iacute;cios Fiscais s&atilde;o um instrumento impulsionador da economia, procurando promover o crescimento das empresas pelo investimento produtivo estrutural e em I&amp;DI, bem como a sua capitaliza&ccedil;&atilde;o.</span></p>\r\n\r\n<p style="text-align: justify;"><span style="background-color:white"><span style="color:#555555">Saiba quais os&nbsp;</span></span><strong>benef&iacute;cios fiscais</strong>&nbsp;atualmente&nbsp;ao disp&ocirc;r&nbsp;sua empresa.</p>\r\n\r\n<ul>\r\n\t<li style="text-align: justify;"><span style="color:#524f4f">Benef&iacute;cios Fiscais de Natureza Contratual</span> <strong><span style="background-color:white"><span style="color:#555555">ao Investimento Produtivo.</span></span></strong></li>\r\n\t<li style="text-align: justify;"><strong><span style="color:#524f4f">Regime Fiscal de Apoio ao Investimento (RFAI)</span>,</strong> <span style="background-color:white"><span style="color:#555555">&eacute; um benef&iacute;cio fiscal, previsto no Decreto-Lei n.&ordm; 162/2014 de 31 de Outubro, que permite &agrave;s empresas deduzir &agrave; coleta apurada uma percentagem do investimento realizado em ativos n&atilde;o correntes (tang&iacute;veis e intang&iacute;veis).</span></span
# Linha de Crédito com Garantia Mútua - "Investe RAM - 2020 - PRR"
# Benefícios Fiscais - Incentivo à Valorização Salarial
# Linha Apoio Turismo + Sustentável
# Linha Capitalizar Mid Caps
# Seguro de Créditos à Exportação de Curto Prazo
# Linha de Microcrédito Turismo para o Interior
# Seguro de Créditos à Exportação de Médio e Longo Prazo
# Linha de Garantia InvestEU - Mobilidade Urbana Sustentável
#  Linha de Apoio à Tesouraria - Incêndios 2025
# Instrumento de Capital - Programa de Coinvestimento Deal-by-Deal
# Linha de Financiamento ao Setor Social
# Seguro Caução
# Linha BPF Invest Export PME – Fundo Maneio
# Fundo de Capital de Risco (FCR)
# Linha IFRRU 2020 - "Regeneração de Comunidades Desfavorecidas"
# Benefícios Fiscais - Incentivo Fiscal à Recuperação (IFR)
# Seguro de Créditos - Setores Metalúrgico, Metalomecânico e de Moldes
# Linha IFRRU 2020 - "Revitalização e Reabilitação Urbana"
# Fundo de Investimento Imobiliário Fechado Turístico - FIIFT
# Fundo de Capital de Risco - 2.º Concurso (Açores e Madeira)
# Programa de Apoio Crescer com o Turismo
# Linha de Crédito Social Investe - "Eixo II"
# Seguro de Créditos Financeiros
# Linha de Crédito para Apoio ao Empreendedorismo e à Criação do Próprio Emprego - "Invest +"
# Fundos de Business Angels
# Linha de Crédito para a "Descarbonização e Economia Circular"
# Linha de Crédito de Apoio à Revitalização Empresarial - "Revitalizar - Médio Prazo ”
# Linha de Crédito de Apoio à Revitalização Empresarial - "Revitalizar - Curto Prazo”
# Benefícios Fiscais - Regime Fiscal de Apoio ao Investimento (RFAI)
# Benefícios Fiscais - Incentivo à Capitalização das Empresas
# Linha de Garantia InvestEU - Investigação, Inovação e Digitalização
# Linha de Crédito com Garantia Mútua Turismo de Portugal - "Programa REVIVE"
# Linha Fomento PT2030 Garantias
# Fundo de Capital de Risco - Portugal Blue
# Linha de Crédito Social Investe - "Eixo I"

# %%
for produto in data['https://financiamento.iapmei.pt/webapi/api/produtos']:
    if produto.get('nome') == 'Fundo de Capital de Risco - Portugal Growth':
        print(produto)
# Out:
# {'id': '0129102a-a42c-4792-82ac-dc585e25db10', 'nome': 'Fundo de Capital de Risco - Portugal Growth', 'descricao': None, 'disponibilidade': False, 'reutilizavel': False, 'tipooperacao': False, 'data': '25/05/2023', 'dados': [{'id': '50379aec-b7ae-408b-abe7-abdb3db191e2', 'textfield': '', 'selectlist': ['Investir', 'Inovar', 'Reforçar Capitais Próprios'], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Necessidades de Financiamento', 'tipocampo': '7', 'grupo': None, 'ordem': 0, 'visivel': False, 'impressao': False}, {'id': '04007a44-4caf-4a0c-ad59-4e66d94f1b70', 'textfield': '27/06/2022 00:00:00', 'selectlist': [], 'checkbox': False, 'data': '2022-06-27T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Data de Início da Linha / Produto', 'tipocampo': '4', 'grupo': None, 'ordem': 200, 'visivel': False, 'impressao': False}, {'id': 'a3ac3a75-9c20-45f1-8e47-34dfac92bf8e', 'textfield': '01/01/0001 00:00:00', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Prazo de Vigência da Linha / Produto', 'tipocampo': '1', 'grupo': None, 'ordem': 300, 'visivel': False, 'impressao': False}, {'id': '55a89322-d9b3-4008-a93a-d827d2b012c7', 'textfield': '01/01/0001 00:00:00', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Data de Fecho da Linha / Produto (suspensão candidaturas)', 'tipocampo': '4', 'grupo': None, 'ordem': 500, 'visivel': False, 'impressao': False}, {'id': '6a473200-562e-4212-ab26-a90adc938e35', 'textfield': '01/01/0001 00:00:00', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Data de Fim Prevista para Linha / Produto', 'tipocampo': '4', 'grupo': None, 'ordem': 600, 'visivel': False, 'impressao': False}, {'id': '87d789b8-c9c4-4910-806d-39ce0eeed7bf', 'textfield': 'Duração média de um ciclo de investimento dos FCR: entre 5 a 10 anos.', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Prazo Global das Operações na Linha / Produto', 'tipocampo': '1', 'grupo': None, 'ordem': 700, 'visivel': False, 'impressao': False}, {'id': 'b5e80333-cd39-4b45-be7b-30b3c82deaa8', 'textfield': '27/06/2032 00:00:00', 'selectlist': [], 'checkbox': False, 'data': '2032-06-27T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Data Limite de Encerramento da Linha / Produto', 'tipocampo': '4', 'grupo': None, 'ordem': 800, 'visivel': False, 'impressao': False}, {'id': '46a79f58-a62b-4ef9-ad8f-38a435ef2226', 'textfield': '€ 100 milhões.', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Montante Global /  Dotação Global da Linha / Produto', 'tipocampo': '1', 'grupo': None, 'ordem': 900, 'visivel': False, 'impressao': False}, {'id': '8ad398bd-58d3-44b8-9227-ba0c55e9e4f2', 'textfield': 'Comparticipação pública nacional: € 50 milhões, via Fundos para a Internacionalização, e sob gestão do Banco Português de Fomento. Comparticipação Fundo Europeu de Investimento: € 50 milhões.', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '', 'anexos': None, 'descricao': 'Fonte de Financiamento da Linha / Produto', 'tipocampo': '1', 'grupo': None, 'ordem': 1000, 'visivel': False, 'impressao': False}, {'id': 'de0e8612-70ae-4f22-99bf-259c0413166e', 'textfield': '', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': '<p>Investimentos de capital-desenvolvimento (<em>growth capital</em>) e aquisi&ccedil;&otilde;es de posi&ccedil;&otilde;es de controlo acionista (<em>buyouts</em>).</p>', 'anexos': None, 'descricao': 'Objetivo', 'tipocampo': '5', 'grupo': None, 'ordem': 1300, 'visivel': True, 'impressao': False}, {'id': 'f0f7a148-7289-4164-970f-1f877a64812e', 'textfield': '', 'selectlist': [], 'checkbox': False, 'data': '0001-01-01T00:00:00', 'editor': "<p style ...

# %%
data['https://financiamento.iapmei.pt/webapi/api/produtos']
# Out:
# [{'id': '0129102a-a42c-4792-82ac-dc585e25db10',
#   'nome': 'Fundo de Capital de Risco - Portugal Growth',
#   'descricao': None,
#   'disponibilidade': False,
#   'reutilizavel': False,
#   'tipooperacao': False,
#   'data': '25/05/2023',
#   'dados': [{'id': '50379aec-b7ae-408b-abe7-abdb3db191e2',
#     'textfield': '',
#     'selectlist': ['Investir', 'Inovar', 'Reforçar Capitais Próprios'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Necessidades de Financiamento',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 0,
#     'visivel': False,
#     'impressao': False},
#    {'id': '04007a44-4caf-4a0c-ad59-4e66d94f1b70',
#     'textfield': '27/06/2022 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2022-06-27T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Início da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 200,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'a3ac3a75-9c20-45f1-8e47-34dfac92bf8e',
#     'textfield': '01/01/0001 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Prazo de Vigência da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 300,
#     'visivel': False,
#     'impressao': False},
#    {'id': '55a89322-d9b3-4008-a93a-d827d2b012c7',
#     'textfield': '01/01/0001 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fecho da Linha / Produto (suspensão candidaturas)',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 500,
#     'visivel': False,
#     'impressao': False},
#    {'id': '6a473200-562e-4212-ab26-a90adc938e35',
#     'textfield': '01/01/0001 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fim Prevista para Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 600,
#     'visivel': False,
#     'impressao': False},
#    {'id': '87d789b8-c9c4-4910-806d-39ce0eeed7bf',
#     'textfield': 'Duração média de um ciclo de investimento dos FCR: entre 5 a 10 anos.',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Prazo Global das Operações na Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 700,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'b5e80333-cd39-4b45-be7b-30b3c82deaa8',
#     'textfield': '27/06/2032 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2032-06-27T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data Limite de Encerramento da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 800,
#     'visivel': False,
#     'impressao': False},
#    {'id': '46a79f58-a62b-4ef9-ad8f-38a435ef2226',
#     'textfield': '€ 100 milhões.',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Montante Global /  Dotação Global da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 900,
#     'visivel': False,
#     'impressao': False},
#    {'id': '8ad398bd-58d3-44b8-9227-ba0c55e9e4f2',
#     'textfield': 'Comparticipação pública nacional: € 50 milhões, via Fundos para a Internacionalização, e sob gestão do Banco Português de Fomento. Comparticipação Fundo Europeu de Investimento: € 50 milhões.',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Fonte de Financiamento da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 1000,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'de0e8612-70ae-4f22-99bf-259c0413166e',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '<p>Investimentos de capital-desenvolvimento (<em>growth capital</em>) e aquisi&ccedil;&otilde;es de posi&ccedil;&otilde;es de controlo acionista (<em>buyouts</em>).</p>',
#     'anexos': None,
#     'descricao': 'Objetivo',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 1300,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'f0f7a148-7289-4164-970f-1f877a64812e',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align: justify;'><strong>Financiamento por Investidor Privado/Intermedi&aacute;rio Financeiro:</strong></p><ul><li style='text-align: justify;'>Comparticipa&ccedil;&atilde;o por fundo direto:&nbsp;4M&euro; a 20M&euro;;</li><li style='text-align: justify;'>Comparticipa&ccedil;&atilde;o privada: no m&iacute;nimo 30% do capital social subscrito nos fundos diretos.</li></ul>",
#     'anexos': None,
#     'descricao': 'Fundos de Capital de Risco (FCR)',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 1301,
#     'visivel': True,
#     'impressao': False},
#    {'id': '1380d604-02c5-42e2-8c09-853ad0c84226',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p>Micro, Pequenas e M&eacute;dias Empresas, com <strong><a href='https://www.iapmei.pt/PRODUTOS-E-SERVICOS/Qualificacao-Certificacao/Certificacao-PME.aspx'><span style='color:#0066cc'>Certifica&ccedil;&atilde;o PME</span></a></strong> e <em>Mid Caps.</em></p>",
#     'anexos': None,
#     'descricao': 'Beneficiários',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 1400,
#     'visivel': True,
#     'impressao': False},
#    {'id': '01065ea3-8130-4526-91ef-24e9396767c3',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align: justify;'>Preferencialmente para investimentos em empresas a operar em Portugal, com potencial de crescimento, nomeadamente atrav&eacute;s de processos de inova&ccedil;&atilde;o produtiva, internacionaliza&ccedil;&atilde;o, e transforma&ccedil;&atilde;o digital.</p>",
#     'anexos': None,
#     'descricao': 'Operações Elegíveis',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2000,
#     'visivel': True,
#     'impressao': False},
#    {'id': '3a95cc0a-6d9d-4b45-bc04-3a8322e4c04f',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<ul><li style='text-align: justify;'>N&atilde;o ser considerada uma empresa em dificuldades, tal como definido na comunica&ccedil;&atilde;o da CE &quot;Orienta&ccedil;&otilde;es relativas aos aux&iacute;lios estatais para a recupera&ccedil;&atilde;o e reestrutura&ccedil;&atilde;o de empresas n&atilde;o financeiras em dificuldade&quot; n.&ordm; 2014/C 249/01;</li><li style='text-align: justify;'>No&nbsp;momento do primeiro investimento pelo Fundo Europeu de Investimento (FEI), a empresa n&atilde;o poder&aacute; atuar em nenhum dos setores econ&oacute;micos referidos como &quot;Setores Restritos do FEI&quot;, nas Orienta&ccedil;&otilde;es relativas aos setores restritos do FEI.</li></ul>",
#     'anexos': None,
#     'descricao': 'Operações Não Elegíveis',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2100,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'cc383472-46d5-4aa0-b547-07230a73dd7d',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '<p>Preferencialmente para investimentos em empresas a operar em Portugal.</p>',
#     'anexos': None,
#     'descricao': 'Condições de Elegibilidade do Beneficiário',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2300,
#     'visivel': True,
#     'impressao': False},
#    {'id': '6ebd49db-5f4e-4860-b9eb-89b55ce239dc',
#     'textfield': '',
#     'selectlist': ['Capital de Risco'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Tipo de Operação',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 3450,
#     'visivel': True,
#     'impressao': False},
#    {'id': '07ca4d13-9e5c-4823-a118-a3cf7f97594e',
#     'textfield': '',
#     'selectlist': ['BPF - Banco Português de Fomento, S.A.'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Entidade Gestora do Produto',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 5400,
#     'visivel': False,
#     'impressao': False},
#    {'id': '35a6b65c-811f-49fe-8649-2035ab69e499',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align: justify;'>O Fundo &eacute; gerido operacionalmente pelo FEI, de acordo com um mandato de gest&atilde;o atribu&iacute;do pelo Banco Portugu&ecirc;s de Fomento ao abrigo do acordo-quadro com os bancos promocionais europeus.</p><p style='text-align: justify;'>Sociedades gestoras selecionadas:</p><p style='text-align: justify;'>&nbsp;- Crest Capital Partners (<em><strong><a href='http://www.crest-cp.com/'><span style='color:#0066ff'>www.crest-cp.com/</span></a></strong></em>)</p><p style='text-align: justify;'>&nbsp;- HCapital (<strong><em><a href='https://hcapital.pt/'><span style='color:#0066ff'>hcapital.pt</span></a></em></strong>)</p><p style='text-align: justify;'>&nbsp;- Vallis Capital Partners (<em><strong><a href='http://www.vallis.pt'><span style='color:#0066ff'>www.vallis.pt</span></a></strong></em>)</p>",
#     'anexos': None,
#     'descricao': 'Entidades Gestoras de FCR',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 5700,
#     'visivel': True,
#     'impressao': False}],
#   'dadosgrupo': [{'id': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#     'nome': 'Caracterização da Empresa',
#     'ordem': 30,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '5863c7f7-5282-421c-b600-f3bf7fa6634e',
#       'textfield': '',
#       'selectlist': ['PME',
#        'Média Empresa',
#        'Pequena Empresa',
#        'Micro Empresa',
#        'Não PME ',
#        'Não PME  de Pequena capitalização  (250 a 500 trabalhadores)',
#        'Não PME de Média capitalização (500 a 3000 trabalhadores)'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Empresa / Empresária(o)',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1100,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'bd9a122a-27d9-4a34-a8da-fc30d4088762',
#       'textfield': '',
#       'selectlist': ['Até 2 anos',
#        'Até 4 anos',
#        'Até 7 anos',
#        'Até 10 anos',
#        'Mais de 10 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tempo de atividade',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1700,
#       'visivel': False,
#       'impressao': False},
#      {'id': '80e5c741-7e44-42fa-917f-8b48194fa093',
#       'textfield': '',
#       'selectlist': ['NUTS II   Norte',
#        'NUTS II  Centro',
#        'NUTS II   Lisboa',
#        'NUTS II  Alentejo',
#        'NUTS II  Algarve',
#        'Região Autónoma da Madeira',
#        'Região Autónoma dos Açores',
#        'Território baixa densidade'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Localização',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'df6208ae-a812-47cd-96ec-ac021101a9fd',
#       'textfield': '',
#       'selectlist': ['Agricultura, produção animal, caça, floresta e pesca (CAE 011 a 032)',
#        'Indústrias extrativas  (CAE 05 a 09)',
#        'Indústrias transformadoras (CAE  10 a 33)',
#        'Eletricidade, gás, vapor, água quente e fria e ar frio (CAE 35)',
#        'Captação, tratamento e distribuição de água; saneamento, gestão de resíduos e despoluição (CAE 36 a 39)',
#        'Construção (CAE 41 a 43)',
#        'Comércio por grosso e a retalho; reparação de veículos automóveis e motociclos  (CAE 45 a 47)',
#        'Transportes e armazenagem  (CAE 49 a 53)',
#        'Alojamento, restauração e similares (CAE 55 e 56)',
#        'Atividades de informação e de comunicação  (CAE 58 a 63)',
#        'Atividades financeiras e de seguros  (CAE 64, 66)',
#        'Atividades imobiliárias (CAE 68)',
#        'Atividades de consultoria, científicas, técnicas e similares  (CAE 69 a 75)',
#        'Atividades administrativas e dos serviços de apoio (CAE 77 a 82)',
#        'Educação (CAE 85)',
#        'Atividades de saúde humana e apoio social  (CAE 86 a 88)',
#        'Outras atividades de serviços  (CAE 94 a 96)',
#        'Atividades artísticas, de espectáculos, desportivas e recreativas (CAE 90  a 93)'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Setor de atividade (CAE Rev.3)',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1900,
#       'visivel': False,
#       'impressao': False}]},
#    {'id': '234806cd-8b76-44c6-b21d-24d5466758ea',
#     'nome': 'Caracterização do Investimento',
#     'ordem': 40,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '203ccba0-779f-4467-ab71-a3d2ce39c457',
#       'textfield': '',
#       'selectlist': ['Aquisição de empresas',
#        'Crescimento / Expansão ',
#        'Inovação',
#        'Investimento',
#        'Reforçar capitais próprios'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Motivação / Estratégia ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1200,
#       'visivel': False,
#       'impressao': False},
#      {'id': '047a1170-9ddd-45e3-a84b-8929f1c23732',
#       'textfield': '',
#       'selectlist': ['Ativo Fixo Tangível', 'Ativo Fixo Intangível'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tipo de investimento',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1600,
#       'visivel': False,
#       'impressao': False},
#      {'id': '80d14629-eb8b-492f-9c46-e7ac55976f1e',
#       'textfield': '',
#       'selectlist': ['Até   € 25.000',
#        'Até  € 50.000',
#        'Até € 100.000',
#        'Até  € 250.000',
#        'Até  € 500.000',
#        'Até  € 1.000.000',
#        'Até € 1.500.000',
#        'Até € 2.000.000',
#        'Até € 4.500.000',
#        'Até € 5.000.000',
#        'Até € 10.000.000',
#        'Até € 20.000.000',
#        'Mais de  € 20.000.000',
#        'Até   € 20.000',
#        'Até   € 75.000'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Montante do financiamento ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': '42e2ca3f-57ee-4b84-9454-8cc8bc436404',
#       'textfield': '',
#       'selectlist': ['Até 5 anos',
#        'Até 6 anos',
#        'Até 7 anos',
#        'Até 8 anos',
#        'Até 9 anos',
#        'Até 10 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Prazo de reembolso',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 2200,
#       'visivel': False,
#       'impressao': False}]}]},
#  {'id': '0bdfe290-5c64-4a3d-8144-b2f0f61d8204',
#   'nome': 'Linha BPF Invest Export PME – Investimento',
#   'descricao': '1.500 M€ ',
#   'disponibilidade': False,
#   'reutilizavel': False,
#   'tipooperacao': False,
#   'data': '14/07/2025',
#   'dados': [{'id': '1981d25d-57bd-4a43-a747-e014376d9510',
#     'textfield': '',
#     'selectlist': ['Investir',
#      'Reforçar Tesouraria / Curto Prazo',
#      'Exportar'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Necessidades de Financiamento',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 0,
#     'visivel': False,
#     'impressao': False},
#    {'id': '0fd296f2-b681-4e4d-8077-ec41e2702662',
#     'textfield': '25/06/2025 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2025-06-25T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Início da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 200,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'b5183195-8b91-46de-a977-8f820e085d5c',
#     'textfield': 'Até 31 de dezembro de 2028',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Prazo de Vigência da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 300,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'f6b4320c-d8a6-4044-b831-cb4e3d06d395',
#     'textfield': 'O prazo pode ser prorrogado por período igual ou diferente, por anúncio do BPF, caso o valor máximo garantido por Linha de Garantia Mútua não se esgote no período em curso.',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Prorrogação Prevista para Vigência da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 400,
#     'visivel': False,
#     'impressao': False},
#    {'id': '0b085ae8-1def-42f9-b429-2e181b60ccbc',
#     'textfield': '31/12/2028 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2028-12-31T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fecho da Linha / Produto (suspensão candidaturas)',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 500,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'deac0910-bb5b-42fc-bd97-33b967f97480',
#     'textfield': '31/12/2028 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2028-12-31T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fim Prevista para Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 600,
#     'visivel': False,
#     'impressao': False},
#    {'id': '8d1ddd03-976e-40d0-ae2d-8526e13038dc',
#     'textfield': 'De 1 até 10 anos',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Prazo Global das Operações na Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 700,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'a1b452fb-95a3-4a97-8b27-69b2e5be9ca1',
#     'textfield': '31/12/2028 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2028-12-31T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data Limite de Encerramento da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 800,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'e9ea9017-aba0-496b-8147-070d59c44c76',
#     'textfield': '€  1.500 milhões.',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Montante Global /  Dotação Global da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 900,
#     'visivel': False,
#     'impressao': False},
#    {'id': '33d5297c-25ce-4bdb-9198-2b71cac1ffb6',
#     'textfield': 'BPF',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Fonte de Financiamento da Linha / Produto',
#     'tipocampo': '1',
#     'grupo': None,
#     'ordem': 1000,
#     'visivel': False,
#     'impressao': False},
#    {'id': '74be3293-c64b-4f6c-a8c0-fdff031ff6c6',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align:justify'>Apoiar&nbsp;o investimento das Empresas Exportadoras Portuguesas, promovendo a sua adapta&ccedil;&atilde;o a novos mercados, com foco nas geografias extracomunit&aacute;rias.</p>",
#     'anexos': None,
#     'descricao': 'Objetivo',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem':

#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2300,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'dc0a64e3-0713-44ea-88b6-e68b7b96bf5f',
#     'textfield': '',
#     'selectlist': ['Crédito', 'Garantia Mútua'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Tipo de Operação',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 3450,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'ee38ce73-9071-47f8-a670-e92a9bd6a24c',
#     'textfield': '',
#     'selectlist': ['Empréstimo Bancário'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Tipo de Produto Bancário',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 3500,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'f93f6f60-04cf-4b7a-b071-d78b215f16ca',
#     'textfield': '',
#     'selectlist': ['BPF - Banco Português de Fomento, S.A.'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Entidade Gestora do Produto',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 5400,
#     'visivel': False,
#     'impressao': False}],
#   'dadosgrupo': [{'id': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#     'nome': 'Crédito',
#     'ordem': 10,
#     'caixa': True,
#     'visivel': True,
#     'dados': [{'id': 'b79043f5-3f08-4dd8-ae7a-97bb6ef67594',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>&nbsp;</p><ul><li>Micro Empresa: 500.000 euros.</li><li>Pequena Empresa: 2.000.000 euros.</li><li>M&eacute;dia Empresa: 5.000.000 euros.</li></ul><p><strong>Convers&atilde;o em valores n&atilde;o reembols&aacute;veis</strong></p><ul><li>Uma parte do empr&eacute;stimo poder&aacute; ser convertida em<strong> subven&ccedil;&atilde;o n&atilde;o reembols&aacute;vel, tendo como limite 20% do valor do financiamento contratado;</strong></li><li>A avalia&ccedil;&atilde;o ser&aacute; feita com<strong> base na IES de 2024, </strong>sendo vari&aacute;vel de acordo com os seguintes<strong> indicadores de desempenho:</strong><ul><li>Montante total dos ativos;</li><li>N&uacute;mero dos postos de trabalho;</li><li>Montante bruto das Exporta&ccedil;&otilde;es;</li><li>Percentagem de exporta&ccedil;&otilde;es sobre o volume de neg&oacute;cios (VN).</li></ul></li><li><strong>Subven&ccedil;&atilde;o de 10% </strong>se a Empresa mantiver os quatro indicadores de desempenho;</li><li><strong>Subven&ccedil;&atilde;o de 15% </strong>se a Empresa aumentar, cumulativamente, 10% em ativos totais e postos de trabalho, mantendo montante exportado e % exporta&ccedil;&otilde;es no volume de neg&oacute;cios;</li><li><strong>Subven&ccedil;&atilde;o de 20% </strong>se a Empresa aumentar, cumulativamente, 20% em ativos totais e postos de trabalho, mantendo montante exportado e % de exporta&ccedil;&otilde;es no volume de neg&oacute;cios;</li></ul><p>Para aceder, basta que <strong>a Empresa assinale, no momento da candidatura, a inten&ccedil;&atilde;o de ativar a convers&atilde;o.</strong></p><ul><li>Sujeito aos limites dispon&iacute;veis no &acirc;mbito do regime de aux&iacute;lios de Estado aplic&aacute;vel;</li><li>No contexto de convers&otilde;es, os indicadores de desempenho aplicam-se exclusivamente &agrave;s exporta&ccedil;&otilde;es destinadas a pa&iacute;ses terceiros (extracomunit&aacute;rios).</li></ul>',
#       'anexos': None,
#       'descricao': 'Financiamento Máximo por Empresa',
#       'tipocampo': '5',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3700,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'fd22a630-d032-42c8-9dbb-9599758d92ff',
#       'textfield': 'Prestações constantes, iguais, mensais, trimestrais, semestrais ou anuais.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Reembolso de Capital',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3750,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'bf7086e3-ec24-4d1d-a12e-e518a1dd9424',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>De 1&nbsp;ano&nbsp;at&eacute; 10 anos.</p>',
#       'anexos': None,
#       'descricao': 'Prazo Máximo da Operação',
#       'tipocampo': '5',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3800,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'bd1bc1b7-0793-4365-87d9-ae540a1cf1e3',
#       'textfield': 'Até 36 meses a contar da data de contratação.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Carência de Capital Máxima',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3900,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'f60fb2d4-bbea-4e0c-bd0b-937f860b01d8',
#       'textfield': 'O spread acresce à taxa fixa de referência que a IC utiliza para o prazo da operação acordada entre a IC e a Empresa.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Taxa de Juro Modalidade Fixa',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4200,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'fd58e85c-ea2d-47ca-9f64-eb12cacc5897',
#       'textfield': 'Euribor, com floor de 0%, a 1, 3, 6 ou 12 meses + spread.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Taxa de Juro Modalidade Variável',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4300,
#       'visivel': True,
#       'impressao': False},
#      {'id': '8cd9073e-a7ec-49c3-b815-16b27ebd4c68',
#       'textfield': 'O Spread máximo será apurado de acordo com notação de risco própria de cada instituição de crédito e maturidade da operação.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Spread',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4500,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'ffc4aadb-f57e-42aa-a1e8-84f6e9ba42c1',
#       'textfield': '0%.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Bonificação da Taxa de Juro',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4600,
#       'visivel': True,
#       'impressao': False}]},
#    {'id': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#     'nome': 'Garantia Mútua',
#     'ordem': 20,
#     'caixa': True,
#     'visivel': True,
#     'dados': [{'id': '9b303343-a2f3-45c4-a10a-c6a5c67b16c2',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>50%.</p>',
#       'anexos': None,
#       'descricao': 'Garantia Mútua',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4700,
#       'visivel': True,
#       'impressao': False},
#      {'id': '0ec04721-85be-4e3b-9de3-2b927591944f',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>A Comiss&atilde;o de garantia ser&aacute; cobrada sobre o montante garantido e calculada de acordo com o rating, tipologia de empresa e maturidade da opera&ccedil;&atilde;o.&nbsp;</p>',
#       'anexos': None,
#       'descricao': 'Comissão de Garantia Mútua ',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4800,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'f71259f7-62c7-4580-b93d-e055be20c349',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': "<p>0%.</p><p>&nbsp;</p><p><a href='https://www.bpfomento.pt/fotos/produtos_documentos/documento_divulgacao_bpf_invest_export_20250618_18317971006852fa20b9b8a.pdf'><strong>Documento de divulga&ccedil;&atilde;o</strong></a></p><p><a href='https://www.bpfomento.pt/fotos/produtos_documentos/bpf_brochura_export_website_830611622685c0b9b33fcf.pdf'><strong>Brochura</strong></a></p><p>&nbsp;</p><p><strong><em>A informa&ccedil;&atilde;o contida nesta p&aacute;gina n&atilde;o dispensa, nem substitui, a consulta e leitura atenta do documento de divulga&ccedil;&atilde;o emitido pela Entidade Gestora.</em></strong></p><p>&nbsp;</p>",
#       'anexos': None,
#       'descricao': 'Bonificação de Comissão de Garantia Mútua',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4900,
#       'visivel': True,
#       'impressao': False}]},
#    {'id': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#     'nome': 'Caracterização da Empresa',
#     'ordem': 30,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': 'c3ffd589-fd22-4537-a663-98719bc8bf79',
#       'textfield': '',
#       'selectlist': ['PME',
#        'Média Empresa',
#        'Pequena Empresa',
#        'Micro Empresa'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Empresa / Empresária(o)',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1100,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'f56b5273-0127-4621-b2cd-a73fdf90e320',
#       'textfield': '',
#       'selectlist': ['Até 2 anos',
#        'Até 4 anos',
#        'Até 7 anos',
#        'Até 10 anos',
#        'Mais de 10 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tempo de atividade',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1700,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'd97c6289-bab9-4bd1-a1fe-de440e6dfbcb',
#       'textfield': '',
#       'selectlist': ['NUTS II   Norte',
#        'NUTS II  Centro',
#        'NUTS II   Lisboa',
#        'NUTS II  Alentejo',
#        'NUTS II  Algarve',
#        'Território baixa densidade'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Localização',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': '87b2bd62-4829-4529-b260-4eebc3a57943',
#       'textfield': '',
#       'selectlist': ['Agricultura, produção animal, caça, floresta e pesca (CAE 011 a 032)',
#        'Indústrias extrativas  (CAE 05 a 09)',
#        'Indústrias transformadoras (CAE  10 a 33)',
#        'Eletricidade, gás, vapor, água quente e fria e ar frio (CAE 35)',
#        'Captação, tratamento e distribuição de água; saneamento, gestão de resíduos e despoluição (CAE 36 a 39)',
#        'Construção (CAE 41 a 43)',
#        'Comércio por grosso e a retalho; reparação de veículos automóveis e motociclos  (CAE 45 a 47)',
#        'Transportes e armazenagem  (CAE 49 a 53)',
#        'Alojamento, restauração e similares (CAE 55 e 56)',
#        'Atividades de informação e de comunicação  (CAE 58 a 63)',
#        'Atividades financeiras e de seguros  (CAE 64, 66)',
#        'Atividades imobiliárias (CAE 68)',
#        'Atividades de consultoria, científicas, técnicas e similares  (CAE 69 a 75)',
#        'Atividades administrativas e dos serviços de apoio (CAE 77 a 82)',
#        'Educação (CAE 85)',
#        'Atividades de saúde humana e apoio social  (CAE 86 a 88)',
#        'Outras atividades de serviços  (CAE 94 a 96)',
#        'Atividades artísticas, de espectáculos, desportivas e recreativas (CAE 90  a 93)'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Setor de atividade (CAE Rev.3)',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1900,
#       'visivel': False,
#       'impressao': False}]},
#    {'id': '234806cd-8b76-44c6-b21d-24d5466758ea',
#     'nome': 'Caracterização do Investimento',
#     'ordem': 40,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '29ad1178-6988-4040-af87-a37bc9294405',
#       'textfield': '',
#       'selectlist': ['Exportação',
#        'Inovação',
#        'Investimento',
#        'Reforçar capitais próprios'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Motivação / Estratégia ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1200,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'fcf3097c-9746-4011-ab6b-d4dc73e9847d',
#       'textfield': '',
#       'selectlist': ['Fundo Maneio/Tesouraria',
#        'Ativo Fixo Tangível',
#        'Ativo Fixo Intangível'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tipo de investimento',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1600,
#       'visivel': False,
#       'impressao': False},
#      {'id': '0b28dddd-419f-43f5-847e-b3ac69c2de2d',
#       'textfield': '',
#       'selectlist': ['Até   € 25.000',
#        'Até  € 50.000',
#        'Até € 100.000',
#        'Até  € 250.000',
#        'Até  € 500.000',
#        'Até  € 1.000.000',
#        'Até € 1.500.000',
#        'Até   € 20.000',
#        'Até   € 75.000'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Montante do financiamento ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': '46203073-b8da-47a5-aac7-3089f8e2c0f9',
#       'textfield': '',
#       'selectlist': ['Até 1 ano',
#        'Até 2 anos',
#        'Até 3 anos',
#        'Até 4 anos',
#        'Até 5 anos',
#        'Até 6 anos',
#        'Até 7 anos',
#        'Até 8 anos',
#        'Até 9 anos',
#        'Até 10 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Prazo de reembolso',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 2200,
#       'visivel': False,
#       'impressao': False}]},
#    {'id': '750f7014-0dfa-46a7-9772-8629b8196ae5',
#     'nome': 'Entidade a contactar',
#     'ordem': 50,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '7ab60b74-0a08-4923-94a0-20f4d9f602fb',
#       'textfield': '',
#       'selectlist': ['BPF-Banco Português de Fomento, S.A. (https://www.bpfomento.pt)'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Entidade a Contactar',
#       'tipocampo': '7',
#       'grupo': '750f7014-0dfa-46a7-9772-8629b8196ae5',
#       'ordem': 5500,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'a843f620-c146-4eb7-86bc-f33bb6d84d3f',
#       'textfield': '',
#       'selectlist': ['Garval, Sociedade de Garantia Mútua, S.A.',
#        'Lisgarante, Sociedade de Garantia Mútua, S.A.',
#        'Agrogarante, Sociedade de Garantia Mútua, S.A.',
#        'Norgarante, Sociedade de Garantia Mútua, S.A.'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Outras entidades aderentes a contactar ',
#       'tipocampo': '7',
#       'grupo': '750f7014-0dfa-46a7-9772-8629b8196ae5',
#       'ordem': 6000,
#       'visivel': True,
#       'impressao': False}]}]},
#  {'id': '0c694ea8-7eec-4e69-bb47-ea9a32cd13e5',
#   'nome': 'Benefícios Fiscais - SIFIDE II',
#   'descricao': 'Sistema de incentivos fiscais em investigação e desenvolvimento empresarial',
#   'disponibilidade': False,
#   'reutilizavel': False,
#   'tipooperacao': False,
#   'data': '16/01/2025',
#   'dados': [{'id': '2d286b2e-71d3-48ee-8d24-c839470918ee',
#     'textfield': '',
#     'selectlist': ['Investir', 'Inovar'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Necessidades de Financiamento',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 0,
#     'visivel': False,
#     'impressao': False},
#    {'id': '41efe598-fbc8-4a4f-b34e-437afaab90ff',
#     'textfield': '01/01/2011 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2011-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Início da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 200,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'af6de4fc-6e7b-4116-9465-5453a6532673',
#     'textfield': '01/01/0001 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fecho da Linha / Produto (suspensão candidaturas)',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 500,
#     'visivel': False,
#     'impressao': False},
#    {'id': 'e4570dc5-4d97-4e0b-93a2-610d8a8106b4',
#     'textfield': '31/12/2025 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2025-12-31T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data de Fim Prevista para Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 600,
#     'visivel': False,
#     'impressao': False},
#    {'id': '7d7c7c60-ed08-4999-900a-a1c4868eaca5',
#     'textfield': '31/12/2025 00:00:00',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '2025-12-31T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Data Limite de Encerramento da Linha / Produto',
#     'tipocampo': '4',
#     'grupo': None,
#     'ordem': 800,
#     'visivel': False,
#     'impressao': False},
#    {'id': '5fb048e3-a7d2-41b2-a59d-b447d9646b54',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align:justify'>O SIFIDE visa&nbsp;aumentar a&nbsp;competitividade das empresas apoiando o seu esfor&ccedil;o em Investiga&ccedil;&atilde;o &amp; Desenvolvimento atrav&eacute;s da dedu&ccedil;&atilde;o &agrave; coleta do IRC de uma percentagem das respetivas despesas de I&amp;D (na parte n&atilde;o comparticipada a fundo perdido pelo Estado ou por Fundos Europeus).</p><p><span style='background-color:white'><span style='color:#1e7da0'>Caracter&iacute;sticas do SIFIDE:&nbsp;</span></span><strong><a href='https://www.youtube.com/watch?v=TPJGkW3TPz0'>SIFIDE 2024 (youtube.com)</a></strong></p>",
#     'anexos': None,
#     'descricao': 'Objetivo',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 1300,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'cc808e11-ed9f-46e3-80b9-be5a744569e0',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<p style='text-align:justify'>Os sujeitos passivos de IRC, residentes em territ&oacute;rio nacional, que exer&ccedil;am, a t&iacute;tulo principal, uma atividade de natureza agr&iacute;cola, industrial, comercial e de servi&ccedil;os e os n&atilde;o residentes com estabelecimento est&aacute;vel nesse territ&oacute;rio.</p>",
#     'anexos': None,
#     'descricao': 'Beneficiários',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 1400,
#     'visivel': True,
#     'impressao': False},
#    {'id': '7e83a8d4-7390-435b-9cf7-9d6c159bccda',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
# ...
#     'anexos': None,
#     'descricao': 'Operações Elegíveis',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2000,
#     'visivel': True,
#     'impressao': False},
#    {'id': '10c24836-e80c-4c72-b10e-c1d1bb247d26',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<ul><li style='text-align:justify'>Opera&ccedil;&otilde;es que se destinem a reestrutura&ccedil;&atilde;o financeira, consolida&ccedil;&atilde;o ou substitui&ccedil;&atilde;o de cr&eacute;ditos e saneamentos;</li><li style='text-align:justify'>Despesas com aquisi&ccedil;&atilde;o de im&oacute;veis;</li><li style='text-align:justify'>Despesas cuja relev&acirc;ncia para a realiza&ccedil;&atilde;o do projeto, n&atilde;o seja fundamentada e reconhecida pelo banco que concede o cr&eacute;dito.</li></ul>",
#     'anexos': None,
#     'descricao': 'Operações Não Elegíveis',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2100,
#     'visivel': True,
#     'impressao': False},
#    {'id': '1cb09670-d5d2-4804-bcf1-c550780da5a1',
#     'textfield': '',
#     'selectlist': [],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': "<ul><li style='text-align:justify'>Estar legalmente constituida;</li><li style='text-align:justify'>N&atilde;o ser detida em mais de 50% pelo Estado;</li><li style='text-align:justify'>Dispor de licenciamento e outros requisitos legais para o exerc&iacute;cio da atividade ou apresentar comprovativo de ter iniciado o respetivo processo;</li><li style='text-align:justify'>Ter a situa&ccedil;&atilde;o regularizada junto da Administra&ccedil;&atilde;o Fiscal e da Seguran&ccedil;a Social;</li><li style='text-align:justify'>Sem incidentes junto da Banca, no Sistema de Garantia M&uacute;tua ou na Central de Responsabilidades de Cr&eacute;dito do Banco de Portugal, salvo justifica&ccedil;&atilde;o aceite pela entidade Banc&aacute;ria e pela Sociedade de Garantia M&uacute;tua;</li><li style='text-align:justify'>Dispor de contabilidade organizada, desde que legalmente exigido;</li><li style='text-align:justify'>Dispor de atestado da qualidade de destinat&aacute;ria ou, no caso das cooperativas, dispor de credencial, emitida pela CASES;</li><li style='text-align:justify'>N&atilde;o se encontrar sujeita a processo de insolv&ecirc;ncia nem preencher os crit&eacute;rios, nos termos do seu direito; nacional, para ficar sujeita a processo de insolv&ecirc;ncia, a pedido dos seus credores.</li></ul>",
#     'anexos': None,
#     'descricao': 'Condições de Elegibilidade do Beneficiário',
#     'tipocampo': '5',
#     'grupo': None,
#     'ordem': 2300,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'a5b3cc02-a215-46a5-9c87-48ee7c6215f3',
#     'textfield': '',
#     'selectlist': ['Crédito', 'Garantia Mútua'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Tipo de Operação',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 3450,
#     'visivel': True,
#     'impressao': False},
#    {'id': '5d25967b-e799-4910-aeb3-ea70d044f824',
#     'textfield': '',
#     'selectlist': ['Empréstimo Bancário'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Tipo de Produto Bancário',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 3500,
#     'visivel': True,
#     'impressao': False},
#    {'id': 'b80cdf40-88f5-4a11-bf63-a5068f15f867',
#     'textfield': '',
#     'selectlist': ['SPGM, S.A.'],
#     'checkbox': False,
#     'data': '0001-01-01T00:00:00',
#     'editor': '',
#     'anexos': None,
#     'descricao': 'Entidade Gestora do Produto',
#     'tipocampo': '7',
#     'grupo': None,
#     'ordem': 5400,
#     'visivel': False,
#     'impressao': False}],
#   'dadosgrupo': [{'id': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#     'nome': 'Crédito',
#     'ordem': 10,
#     'caixa': True,
#     'visivel': True,
#     'dados': [{'id': '121c3e44-af93-41fd-bdec-daa52be5570f',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>At&eacute; &euro;100.000, tendo como limite 95% do montante envolvido no&nbsp;projeto.</p>',
#       'anexos': None,
#       'descricao': 'Financiamento Máximo por Empresa',
#       'tipocampo': '5',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3700,
#       'visivel': True,
#       'impressao': False},
#      {'id': '55006903-577e-4366-ba81-4c47941fb138',
#       'textfield': 'Prestações constantes, trimestrais e postecipadas.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Reembolso de Capital',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3750,
#       'visivel': True,
#       'impressao': False},
#      {'id': '7bfb44a3-1a03-42c9-8b4c-742ee0a14fb2',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>7 anos.</p>',
#       'anexos': None,
#       'descricao': 'Prazo Máximo da Operação',
#       'tipocampo': '5',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3800,
#       'visivel': True,
#       'impressao': False},
#      {'id': '7d328198-56db-4f6b-bb5c-b24d923f2abb',
#       'textfield': 'Até 24 meses.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Carência de Capital Máxima',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 3900,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'af0c84c5-1fac-4038-b226-7c615287dcd5',
#       'textfield': 'Euribor a 3 meses + spread.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Taxa de Juro Modalidade Variável',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4300,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'dad3d4ec-a1ce-46a6-b014-39b09f6b3a82',
#       'textfield': '3,75%.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Spread',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4500,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'b3884925-f47c-4030-801f-1ae83fc22775',
#       'textfield': '1,75%.',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Bonificação da Taxa de Juro',
#       'tipocampo': '1',
#       'grupo': 'deba90f1-99e5-4bb0-9178-9952810b5263',
#       'ordem': 4600,
#       'visivel': True,
#       'impressao': False}]},
#    {'id': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#     'nome': 'Garantia Mútua',
#     'ordem': 20,
#     'caixa': True,
#     'visivel': True,
#     'dados': [{'id': 'aae94d17-defb-4478-aae6-0485a504c5fd',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>80% do capital em d&iacute;vida em cada momento.</p>',
#       'anexos': None,
#       'descricao': 'Garantia Mútua',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4700,
#       'visivel': True,
#       'impressao': False},
#      {'id': '4e1a6531-384b-414d-befa-926cb023017a',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '<p>2% , liquidada trimestral e antecipadamente.</p>',
#       'anexos': None,
#       'descricao': 'Comissão de Garantia Mútua ',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4800,
#       'visivel': True,
#       'impressao': False},
#      {'id': 'ec5c02ed-0fc5-4caf-8c44-1ff78a0179b4',
#       'textfield': '',
#       'selectlist': [],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': "<p>100%.</p><p>&nbsp;</p><p style='text-align:justify'><em><strong><span style='color:#1e7da0'>A informa&ccedil;&atilde;o contida nesta p&aacute;gina n&atilde;o dispensa, nem substitui, a consulta e leitura atenta do documento de divulga&ccedil;&atilde;o emitido pela Entidade Gestora.</span></strong></em></p>",
#       'anexos': None,
#       'descricao': 'Bonificação de Comissão de Garantia Mútua',
#       'tipocampo': '5',
#       'grupo': '959ea197-a7d1-4f78-85e7-a96080ba64f2',
#       'ordem': 4900,
#       'visivel': True,
#       'impressao': False}]},
#    {'id': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#     'nome': 'Caracterização da Empresa',
#     'ordem': 30,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': 'ac00e239-d88f-4820-96f6-6072439bf6af',
#       'textfield': '',
#       'selectlist': ['Associações de Desenvolvimento Local',
#        'Cooperativas',
#        'Entidades sem fins lucrativos',
#        'Instituições Particulares de Solidariedade Social',
#        'Misericórdias',
#        'Mutualidades',
#        'Outras entidades da economia social sem fins lucrativos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Outras entidades',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1600,
#       'visivel': False,
#       'impressao': False},
#      {'id': '5f66f708-44b4-4520-97eb-15cb5ea2ac0f',
#       'textfield': '',
#       'selectlist': ['Até 2 anos',
#        'Até 4 anos',
#        'Até 7 anos',
#        'Até 10 anos',
#        'Mais de 10 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tempo de atividade',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1700,
#       'visivel': False,
#       'impressao': False},
#      {'id': '168b1272-125e-42aa-8b0c-4e67a7bd2397',
#       'textfield': '',
#       'selectlist': ['NUTS II   Norte',
#        'NUTS II  Centro',
#        'NUTS II   Lisboa',
#        'NUTS II  Alentejo',
#        'NUTS II  Algarve',
#        'Região Autónoma da Madeira',
#        'Região Autónoma dos Açores',
#        'Território baixa densidade'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Localização',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': '274d35e9-fac7-4f97-b933-9edb205b870a',
#       'textfield': '',
#       'selectlist': ['Agricultura, produção animal, caça, floresta e pesca (CAE 011 a 032)',
#        'Indústrias extrativas  (CAE 05 a 09)',
#        'Indústrias transformadoras (CAE  10 a 33)',
#        'Eletricidade, gás, vapor, água quente e fria e ar frio (CAE 35)',
#        'Captação, tratamento e distribuição de água; saneamento, gestão de resíduos e despoluição (CAE 36 a 39)',
#        'Construção (CAE 41 a 43)',
#        'Comércio por grosso e a retalho; reparação de veículos automóveis e motociclos  (CAE 45 a 47)',
#        'Transportes e armazenagem  (CAE 49 a 53)',
#        'Alojamento, restauração e similares (CAE 55 e 56)',
#        'Atividades de informação e de comunicação  (CAE 58 a 63)',
#        'Atividades financeiras e de seguros  (CAE 64, 66)',
#        'Atividades imobiliárias (CAE 68)',
#        'Atividades de consultoria, científicas, técnicas e similares  (CAE 69 a 75)',
#        'Atividades administrativas e dos serviços de apoio (CAE 77 a 82)',
#        'Educação (CAE 85)',
#        'Atividades de saúde humana e apoio social  (CAE 86 a 88)',
#        'Outras atividades de serviços  (CAE 94 a 96)',
#        'Atividades artísticas, de espectáculos, desportivas e recreativas (CAE 90  a 93)'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Setor de atividade (CAE Rev.3)',
#       'tipocampo': '7',
#       'grupo': '2a13d290-ba86-4da7-b8c8-fc05405b58e1',
#       'ordem': 1900,
#       'visivel': False,
#       'impressao': False}]},
#    {'id': '234806cd-8b76-44c6-b21d-24d5466758ea',
#     'nome': 'Caracterização do Investimento',
#     'ordem': 40,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '2ef96baa-8f67-4d19-8b9c-079ded502ebe',
#       'textfield': '',
#       'selectlist': ['Crescimento / Expansão ',
#        'Curto Prazo / Tesouraria',
#        'Inovação',
#        'Investimento',
#        'Economia Social'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Motivação / Estratégia ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1200,
#       'visivel': False,
#       'impressao': False},
#      {'id': '06aced8e-2441-4474-af7b-6586056d39ae',
#       'textfield': '',
#       'selectlist': ['Fundo Maneio/Tesouraria', 'Ativo Fixo Tangível'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Tipo de investimento',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1600,
#       'visivel': False,
#       'impressao': False},
#      {'id': '71041db2-30b4-4740-ba9a-e32d2576e6a6',
#       'textfield': '',
#       'selectlist': ['Até   € 25.000',
#        'Até  € 50.000',
#        'Até € 100.000',
#        'Até  € 250.000'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Montante do financiamento ',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 1800,
#       'visivel': False,
#       'impressao': False},
#      {'id': 'b08b83e4-2b1b-43b4-a049-987bdfb4700a',
#       'textfield': '',
#       'selectlist': ['Até 1 ano',
#        'Até 2 anos',
#        'Até 3 anos',
#        'Até 4 anos',
#        'Até 5 anos',
#        'Até 6 anos',
#        'Até 7 anos'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Prazo de reembolso',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 2200,
#       'visivel': False,
#       'impressao': False},
#      {'id': '6ccce4f3-3639-4bf1-8a01-8419350e9007',
#       'textfield': '',
#       'selectlist': ['Economia Social'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Linhas específicas',
#       'tipocampo': '7',
#       'grupo': '234806cd-8b76-44c6-b21d-24d5466758ea',
#       'ordem': 4000,
#       'visivel': False,
#       'impressao': False}]},
#    {'id': '750f7014-0dfa-46a7-9772-8629b8196ae5',
#     'nome': 'Entidade a contactar',
#     'ordem': 50,
#     'caixa': False,
#     'visivel': False,
#     'dados': [{'id': '362b2a25-36f4-4950-8cde-e83994ff6863',
#       'textfield': '',
#       'selectlist': ['Banco BPI, S.A.',
#        'Banco Comercial Português, S.A.',
#        'Banco Português de Gestão, S.A.',
#        'Caixa Central de Crédito Agrícola Mútuo, CRL',
#        'Caixa Económica Montepio Geral, S.A.',
#        'Caixa Geral de Depósitos, S.A.',
#        'Novo Banco, S.A.'],
#       'checkbox': False,
#       'data': '0001-01-01T00:00:00',
#       'editor': '',
#       'anexos': None,
#       'descricao': 'Bancos aderentes a contactar',
#       'tipocampo': '7',
#       'grupo': '750f7014-0dfa-46a7-9772-8629b8196ae5',
#       'ordem': 5600,
#       'visivel': True,
#       'impressao': False}]}]}]

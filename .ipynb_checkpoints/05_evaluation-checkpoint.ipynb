# %% [markdown]
# ## Libraries

# %%
import chatbot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
index, metadata = chatbot.load_faiss_index(chatbot.VECTOR_DIR)
print("Index and metadata loaded.")
# Out:
# Index and metadata loaded.

# %%
dataset= [
  {
    "question": "O que é o Alentejo 2030?",
    "answer": "O Alentejo 2030 é um programa que transforma vidas impulsionando a inovação, a sustentabilidade e o crescimento da região. Ajuda a beneficiar dos Fundos Europeus disponíveis e contribui para o desenvolvimento do Alentejo."
  },
  {
    "question": "Qual é o propósito do Algarve 2030?",
    "answer": "O Algarve 2030 visa promover a competitividade e diversificação da economia e a sustentabilidade regional, valorizando o território e as pessoas."
  },
  {
    "question": "Quais são os objetivos estratégicos do Centro 2030?",
    "answer": "Centro + Competitivo (investindo em inovação, digitalização, competitividade das empresas, competências para especialização inteligente e empreendedorismo), Centro + Verde (investindo em sustentabilidade, economia circular, transição energética e mobilidade urbana sustentável), Centro + Conectado (através de intervenções de modernização, requalificação e reforço de troços da rede ferroviária regional), Centro + coeso e + próximo dos cidadãos (através de apoio a estratégias de desenvolvimento territorial e desenvolvimento urbano sustentável), Centro + Social e Inclusivo (apoiando o emprego de qualidade, educação, competências, inclusão social e igual acesso aos cuidados de saúde)."
  },
  {
    "question": "O que é o COMPETE 2030?",
    "answer": "O COMPETE 2030 é um programa para Inovação e Transição Digital, visando um Portugal mais competitivo, sustentável e inclusivo preparado para o futuro."
  },
  {
    "question": "O que é o Fundo Social Europeu?",
    "answer": "O Fundo Social Europeu (FSE) é o principal instrumento da UE para apoiar o emprego nos Estados-Membros, bem como ajudar as pessoas a obter melhores empregos e garantir oportunidades de emprego mais justas para todos os cidadãos da UE."
  },
  {
    "question": "Qual é o propósito do Fundo para o Asilo, a Migração e a Integração (FAMI)?",
    "answer": "O FAMI visa contribuir para a gestão eficiente dos fluxos migratórios e melhorar a implementação e o desenvolvimento da política comum da UE em matéria de asilo e imigração. Tem quatro objetivos principais: reforçar e desenvolver todos os aspetos do Sistema Europeu Comum de Asilo, apoiar a migração legal para os Estados-Membros da UE em conformidade com as respetivas necessidades económicas e sociais, promover a integração efetiva dos nacionais de países não pertencentes à UE, e promover estratégias de regresso nos Estados-Membros, com ênfase na sustentabilidade dos regressos e na readmissão efetiva nos países de origem."
  },
  {
    "question": "Qual é o papel do Fundo Europeu de Desenvolvimento Regional (FEDER)?",
    "answer": "O Fundo Europeu de Desenvolvimento Regional (FEDER) visa reduzir as disparidades regionais, impulsionar o crescimento económico e reforçar a coesão entre as regiões da Europa. Apoia investimentos em investigação e inovação, PME, agenda digital e economia com baixas emissões de carbono."
  },
  {
    "question": "Qual é o propósito do Fundo para uma Transição Justa (FTJ)?",
    "answer": "O Fundo para uma Transição Justa (FTJ) visa apoiar as pessoas, a economia e o ambiente em territórios que enfrentam desafios socioeconómicos graves decorrentes da transição para uma UE neutra em carbono. Contribui para abordar os impactos sociais, no emprego, económicos e ambientais da transição da UE para as suas metas de energia e clima para 2030 e para uma economia da União neutra em carbono até 2050."
  },
  {
    "question": "Qual é o propósito do Instrumento de Apoio Financeiro à Gestão das Fronteiras e à Política de Vistos (IGFV)?",
    "answer": "O IGFV visa assegurar uma gestão europeia integrada das fronteiras externas que seja rigorosa e efetiva, contribuir para um nível elevado de segurança interna, salvaguardar a livre circulação de pessoas na UE, e respeitar o direito da UE e as obrigações internacionais."
  },
  {
    "question": "Quais são as principais áreas de ação do Lisboa 2030?",
    "answer": "As principais áreas de ação são Inovação e competitividade (investindo em investigação e inovação, investimentos produtivos, criando conhecimento, aumentando a competitividade das PME e desenvolvendo competências para especialização inteligente), Inclusão social (adquirindo equipamentos hospitalares e de educação, apoio ao emprego, promoção do emprego altamente qualificado, formação modular certificada, apoio à inclusão/inovação social e ao sucesso escolar), Sustentabilidade e resiliência (investimentos em eficiência energética na administração pública local, ações de mitigação das alterações climáticas, economia circular, conservação da natureza, biodiversidade, património natural e mobilidade urbana sustentável), Desenvolvimento urbano (promovendo a mudança transformadora e a cidade de proximidade, através de apoio a equipamentos escolares, regeneração urbana e parcerias urbanas)."
  },
  {
    "question": "Quais são os objetivos estratégicos do Norte 2030?",
    "answer": "Os objetivos estratégicos são Norte Mais Competitivo (reforçando a capacidade de investigação e inovação, aumentando o valor acrescentado nos produtos e serviços feitos no Norte, para crescer mais e melhor), Norte Mais Verde (promovendo a sustentabilidade ambiental, economia circular, transição energética e resiliência climática), Norte Mais Social (promovendo a inclusão social, educação, formação e emprego), Norte Mais Próximo dos Cidadãos (promovendo a coesão territorial, desenvolvimento urbano e acesso a serviços), Norte Mais Conectado (melhorando a conectividade, transportes e infraestrutura digital), Norte Mais Neutro em Carbono e com Transição Justa (apoiando a transição para a neutralidade carbónica e transição justa para territórios afetados)."
  },
  {
    "question": "O que é o Portugal 2030?",
    "answer": "O Portugal 2030 é a implementação do Acordo de Parceria entre Portugal e a Comissão Europeia para aplicar 23 mil milhões de euros dos fundos europeus em projetos que estimulem e desenvolvam a economia portuguesa entre 2021 e 2027."
  }
]

# %% [markdown]
# ## RAGAS

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
import time

# ---------------- Embedding Helper ----------------
def get_embedding(text: str):
    """
    Returns embedding using your OpenAI client
    """
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return np.array(response.data[0].embedding, dtype=np.float32).reshape(1, -1)

# ---------------- Core Metrics ----------------
def f1_score(pred, ref):
    if not pred: return 0.0
    pred_tokens = pred.split()
    ref_tokens = ref.split()
    common = Counter(pred_tokens) & Counter(ref_tokens)
    num_same = sum(common.values())
    if num_same == 0: return 0.0
    precision = num_same / len(pred_tokens)
    recall = num_same / len(ref_tokens)
    return 2 * precision * recall / (precision + recall)

def exact_match(pred, ref):
    return int(pred.strip() == ref.strip())

def conciseness_score(generated, reference):
    return len(reference.split()) / max(1, len(generated.split()))

# ---------------- Embedding-based Retrieval Success ----------------
def retrieval_success_semantic(retrieved_docs, reference, threshold=0.75):
    """
    Returns 1 if any retrieved doc has semantic similarity above threshold with reference
    """
    ref_emb = get_embedding(reference)
    for doc in retrieved_docs:
        doc_text = doc.get("answer","")
        doc_emb = get_embedding(doc_text)
        sim = cosine_similarity(ref_emb, doc_emb)[0][0]
        if sim >= threshold:
            return 1
    return 0

# ---------------- Embedding-based Grounding ----------------
def grounding_score_semantic(generated, retrieved_docs):
    """
    Fraction of generated answer semantically supported by retrieved docs
    """
    gen_emb = get_embedding(generated)
    doc_embs = np.vstack([get_embedding(doc.get("answer","")) for doc in retrieved_docs])
    sims = cosine_similarity(gen_emb, doc_embs)[0]
    # Use max similarity for each doc
    if len(sims) == 0:
        return 0.0
    return float(np.max(sims))

# %% [markdown]
# **Pipeline**

# %%
def evaluate_rag_semantic(dataset, index, metadata, k=5, model="gpt-4o-mini"):
    results = []

    for item in dataset:
        question = item["question"]
        reference = item["answer"]

        # Generate answer
        start_time = time.time()
        generated_answer, retrieved_docs = chatbot.answer(question, index, metadata, k=k, model=model)
        latency = time.time() - start_time

        if isinstance(generated_answer, tuple):
            generated_answer = generated_answer[0]

        # Metrics
        retrieval_success = retrieval_success_semantic(retrieved_docs, reference, threshold=0.7)
        grounding = grounding_score_semantic(generated_answer, retrieved_docs)
        f1 = f1_score(generated_answer, reference)
        em = exact_match(generated_answer, reference)
        conciseness = conciseness_score(generated_answer, reference)
        semantic_sim = semantic_similarity_score(generated_answer, [reference])

        results.append({
            "Question": question,
            "Reference Answer": reference,
            "Generated Answer": generated_answer,
            "Retrieval Success (semantic)": retrieval_success,
            "Grounding (semantic)": grounding,
            "F1": f1,
            "Exact Match": em,
            "Conciseness": conciseness,
            "Semantic Similarity": semantic_sim,
            "Latency (s)": latency
        })

    df = pd.DataFrame(results)
    return df

# %%
df_results = evaluate_rag_semantic(dataset, index, metadata, k=5)
# Out:
# Assistente: O Alentejo 2030 é um programa que visa transformar vidas na região do Alentejo através da inovação, sustentabilidade e crescimento. O programa inclui uma lista de operações aprovadas, um comité de acompanhamento, documentação, legislação, avisos de concurso, um plano anual de avisos e regras de comunicação, com o objetivo de impulsionar o desenvolvimento regional. (Fontes: [portugal2030], [alentejo_portugal2030])
#
# Assistente: O propósito do Algarve 2030 é promover a competitividade, a diversificação da economia e a sustentabilidade regional, valorizando tanto o território como as pessoas da região do Algarve. O programa visa apoiar diversas áreas e implementar um modelo de governação específico, com critérios de seleção para as operações a serem apoiadas. (Fontes: [algarve_portugal2030])
#
# Assistente: Os objetivos estratégicos do Centro 2030 incluem:
#
# 1. Promover a competitividade da economia.
# 2. Fomentar a sustentabilidade ambiental.
# ...

# %%
df_results.describe()
# Out:
#        Retrieval Success         F1  Exact Match  Grounding  Conciseness  \
# count               12.0  12.000000         12.0       12.0    12.000000
# mean                 0.0   0.351335          0.0        0.0     0.976598
# std                  0.0   0.154528          0.0        0.0     0.598006
# min                  0.0   0.157143          0.0        0.0     0.298701
# 25%                  0.0   0.241034          0.0        0.0     0.535714
# 50%                  0.0   0.318430          0.0        0.0     0.656183
# 75%                  0.0   0.415686          0.0        0.0     1.565934
# max                  0.0   0.673267          0.0        0.0     1.945455
#
#        Semantic Similarity  Latency (s)
# count            12.000000    12.000000
# mean              0.834839     4.019828
# std               0.097082     0.652582
# min               0.642550     3.292277
# 25%               0.799512     3.617632
# 50%               0.856976     3.994243
# ...

# %%
pd.set_option('display.max_colwidth', None)
df_results.iloc[:1, :]
# Out:
#                    Question  \
# 0  O que é o Alentejo 2030?
#
#                                                                                                                                                                                                                 Reference Answer  \
# 0  O Alentejo 2030 é um programa que transforma vidas impulsionando a inovação, a sustentabilidade e o crescimento da região. Ajuda a beneficiar dos Fundos Europeus disponíveis e contribui para o desenvolvimento do Alentejo.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                    Generated Answer  \
# ...

# %%
metrics = ["precision@k", "recall@k", "answer_similarity", "groundedness"]

plt.figure(figsize=(12, 6))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[metric], bins=10, kde=True, color="skyblue")
    plt.title(metric)
    plt.xlabel(metric)
    plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bot-Based

# %% [markdown]
# You can explicitly say:
#
# Increasing k:
#
# ↑ Recall
#
# ↓ Precision
#
# ↑ Groundedness (usually)
#
# Better chunking:
#
# ↑ Precision
#
# ↑ Groundedness
#
# Larger chunks:
#
# ↑ Recall
#
# ↓ Precision
#
# These trade-offs show deep understanding.

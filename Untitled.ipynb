# %%
import chatbot
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
from dotenv import load_dotenv
from openai import OpenAI
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import time

# %%
load_dotenv()
client = OpenAI()

index, metadata = chatbot.load_faiss_index(chatbot.VECTOR_DIR)
bm25=chatbot.build_bm25(metadata)
print("Index and metadata loaded.")
# Out:
# Index and metadata loaded.

# %%
with open("evaluation/evaluation_dataset_v2.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
def json_to_documents(data: dict):
    documents = []

    for source, content in data.items():
        qa_list = content.get("perguntas_respostas", [])

        for item in qa_list:
            documents.append({
                "question": item.get("pergunta", ""),
                "answer": item.get("resposta", ""),
                "source": source
            })

    return documents

# %%
documents = json_to_documents(data)
documents
# Out:
# [{'question': 'O que é o Alentejo 2030?',
#   'answer': 'O Alentejo 2030 é um programa que visa transformar vidas na região do Alentejo, impulsionando a inovação, a sustentabilidade e o crescimento regional, além de facilitar o acesso aos Fundos Europeus disponíveis.',
#   'source': 'alentejo2030'},
#  {'question': 'Quais são alguns dos eventos programados para o Alentejo 2030?',
#   'answer': "Alguns dos eventos programados incluem um workshop sobre Prospetivas e Políticas Públicas em 15 de dezembro de 2025, uma conferência e espetáculo sobre Inteligência Artificial em 27 de novembro de 2025, e um concerto intitulado 'Ecoando a voz do Alentejo' em 16 de novembro de 2025.",
#   'source': 'alentejo2030'},
#  {'question': 'Qual foi a decisão da Comissão Europeia em relação ao Alentejo 2030?',
#   'answer': 'A Comissão Europeia aprovou, em 15 de dezembro de 2025, a reprogramação do Programa Regional do Alentejo 2030, permitindo alinhar os fundos europeus com novas prioridades estratégicas e desafios emergentes da região.',
#   'source': 'alentejo2030'},
#  {'question': 'Quais são algumas das novas prioridades introduzidas pela reprogramação do Alentejo 2030?',
#   'answer': 'As novas prioridades incluem a Defesa, a Água, a Habitação a preços acessíveis e sustentável, e Competências para a descarbonização, além de investimentos em áreas como Investigação, inovação, digitalização, eficiência energética e inclusão social.',
#   'source': 'alentejo2030'},
#  {'question': 'Como a reprogramação do Alentejo 2030 impacta o apoio ao emprego e à formação?',
#   'answer': 'A reprogramação introduz maior flexibilidade no apoio ao emprego e à formação, permitindo financiar equipamentos de formação e criando uma nova prioridade dedicada à habitação acessível e sustentável, reforçando a dimensão social da transição justa.',
#   'source': 'alentejo2030'},
#  {'question': 'Qual é o objetivo principal do Programa Algarve 2030?',
#   'answer': 'O Programa Algarve 2030 destina-se a promover a competitividade e diversificação da economia e a sustentabilidade regional, valorizando o território e as pessoas.',
#   'source': 'algarve2030'},
#  {'question': 'Quais são algumas das iniciativas relacionadas ao ciclo urbano da água mencionadas no texto?',
#   'answer': 'As iniciativas incluem a redução de perdas nas redes urbanas de água, reabilitação de infraestruturas obsoletas, prevenção e mitigação da intrusão salina, reutilização de águas residuais tratadas para fins não potáveis e expansão e modernização das redes de saneamento.',
#   'source': 'algarve2030'},
#  {'question': 'Qual é a quantia total de investimentos que os Municípios do Algarve e a empresa Águas do Algarve candidataram a fundos estruturais de coesão?',
#   'answer': 'Os Municípios do Algarve e a empresa Águas do Algarve candidataram mais de 100 milhões de euros a fundos estruturais de coesão geridos pelo Programa Regional ALGARVE 2030.',
#   'source': 'algarve2030'},
#  {'question': 'Como o Programa Algarve 2030 está alinhado com as diretrizes da Comissão Europeia sobre eficiência hídrica?',
#   'answer': 'O Programa Algarve 2030 está alinhado com a Comunicação europeia que pede uma redução de 10% na eficiência hídrica até 2030, promovendo uma gestão mais eficiente e resiliente dos recursos hídricos e adotando medidas concretas de poupança e eficiência no uso da água.',
#   'source': 'algarve2030'},
#  {'question': 'Quais são as áreas de investimento previstas no Programa Algarve 2030 relacionadas à água?',
#   'answer': 'As áreas de investimento incluem o aumento da eficiência da rede de abastecimento de água e saneamento, a redução de perdas, o aproveitamento de águas residuais tratadas para usos secundários, como a rega de espaços verdes, e a monitorização inteligente dos recursos hídricos.',
#   'source': 'algarve2030'},
#  {'question': 'Qual é o objetivo principal do Programa Centro 2030?',
#   'answer': 'O Programa Centro 2030 tem como objetivo promover a competitividade da economia, a sustentabilidade ambiental e a valorização do território e das pessoas na região Centro de Portugal, dentro do quadro da Política de Coesão da União Europeia.',
#   'source': 'centro2030'},
#  {'question': 'O que foi aprovado pela Comissão Europeia em relação ao Programa Centro 2030?',
#   'answer': 'A Comissão Europeia aprovou a proposta de reprogramação do Programa Regional do Centro 2021-2027 (CENTRO 2030), que inclui o alargamento do financiamento para habitação social e a preços acessíveis, apoio a projetos de tecnologias críticas e projetos empresariais na área da defesa.',
#   'source': 'centro2030'},
#  {'question': 'Qual é a principal aposta da reprogramação do Centro 2030?',
#   'answer': 'A principal aposta da reprogramação do Centro 2030 é a área da habitação, com um financiamento de quase 200 milhões de euros destinado à ampliação do parque público de habitação, promovendo a renovação de edifícios devolutos ou vagos para oferecer habitação sustentável e acessível.',
#   'source': 'centro2030'},
#  {'question': 'Como o Programa Centro 2030 combate a fraude nos fundos comunitários?',
#   'answer': 'O Programa Centro 2030 combate a fraude nos fundos comunitários alinhando-se com os Regulamentos Europeus e a Estratégia Nacional Antifraude (ENAF), implementando um sistema de gestão e controlo rigoroso, além de promover ações de prevenção, deteção e punição de práticas fraudulentas.',
#   'source': 'centro2030'},
#  {'question': 'Quais são algumas das áreas de apoio incluídas na reprogramação do Centro 2030?',
#   'answer': 'As áreas de apoio incluídas na reprogramação do Centro 2030 abrangem a habitação social e a preços acessíveis, tecnologias críticas, e projetos empresariais na área da defesa, visando a criação ou expansão da capacidade produtiva industrial no setor.',
#   'source': 'centro2030'},
#  {'question': 'Qual é o objetivo principal do programa COMPETE 2030?',
#   'answer': 'O objetivo principal do programa COMPETE 2030 é tornar Portugal mais competitivo, sustentável e inclusivo, através da digitalização, inovação e qualificação das PME, além de promover a descarbonização e a inclusão social.',
#   'source': 'compete2030'},
#  {'question': 'Quais são os três pilares principais do programa COMPETE 2030?',
#   'answer': 'Os três pilares principais do programa COMPETE 2030 são: 1) Portugal + Competitivo, que foca na digitalização, investigação e inovação; 2) Portugal + Verde, que visa a descarbonização e a produção de energias renováveis; e 3) Portugal + Social, que se concentra na qualificação e inclusão de trabalhadores.',
#   'source': 'compete2030'},
#  {'question': 'Como o programa COMPETE 2030 apoia as empresas?',
#   'answer': 'O programa COMPETE 2030 apoia as empresas através de financiamento para projetos de digitalização, descarbonização e capacitação de trabalhadores, visando aumentar a competitividade e a adaptação às mudanças do mercado.',
#   'source': 'compete2030'},
#  {'question': 'O que é o canal +Transparente mencionado no texto?',
#   'answer': 'O canal +Transparente é um canal seguro para submeter denúncias que devem ser analisadas pela organização, conforme a Lei n.º 93/2021. Ele pode ser utilizado por qualquer pessoa, garantindo a confidencialidade e a possibilidade de anonimato.',
#   'source': 'compete2030'},
#  {'question': 'Quando e onde ocorrerá a apresentação da Rede de Fornecedores Inovadores?',
#   'answer': 'A apresentação da Rede de Fornecedores Inovadores ocorrerá no dia 8 de Maio de 2025, às 11:30h, através da plataforma Microsoft Teams, e visa integrar empresas portuguesas em cadeias de valor globais.',
#   'source': 'compete2030'},
#  {'question': 'O que é o StartUP Visa?',
#   'answer': 'O StartUP Visa é um programa de acolhimento de empreendedores estrangeiros que desejam desenvolver um projeto de empreendedorismo e/ou inovação em Portugal, visando a concessão de visto de residência ou autorização de residência para imigrantes empreendedores.',
#   'source': 'iapmei'},
#  {'question': 'Quais são os principais serviços oferecidos pelo IAPMEI?',
#   'answer': 'Os principais serviços oferecidos pelo IAPMEI incluem certificação PME, apoio empresarial e formação, incentivos e financiamento, e programas de empreendedorismo qualificado e inovador, como o StartUP Voucher e o Tech Visa.',
#   'source': 'iapmei'},
#  {'question': 'Como as empresas podem obter a certificação PME?',
#   'answer': 'As empresas que desejam obter a certificação como micro, pequena ou média empresa devem utilizar a opção disponível na Área Empresas do IAPMEI, onde podem acessar informações sobre o processo de certificação.',
#   'source': 'iapmei'},
#  {'question': 'Quais são os indicadores de atividade para 2024 mencionados no texto?',
#   'answer': 'Os indicadores de atividade para 2024 incluem mais de 17.000 candidaturas submetidas para incentivos PT2030 e PRR, com um incentivo contratado de aproximadamente 4,6 milhões de euros e pagamentos de cerca de 1,9 milhões de euros. Além disso, há mais de 1.000 candidaturas contratadas nas Linhas de Apoio à Tesouraria, totalizando um montante global de cerca de 37 milhões de euros.',
#   'source': 'iapmei'},
#  {'question': 'O que é a Academia de PME?',
#   'answer': 'A Academia de PME é uma iniciativa do IAPMEI que oferece formação e ferramentas disponíveis para apoiar os negócios, visando promover o empreendedorismo e a inovação entre pequenas e médias empresas.',
#   'source': 'iapmei'},
#  {'question': 'Qual é o objetivo principal do Programa Lisboa 2030?',
#   'answer': 'O Programa Lisboa 2030 destina-se a promover a competitividade da economia, a sustentabilidade ambiental e a valorização do território e das pessoas na região.',
#   'source': 'lisboa2030'},
#  {'question': 'O que é o Espaço de Descoberta Empreendedora (EDE) e qual foi seu propósito na sessão de 27 de novembro?',
#   'answer': 'O Espaço de Descoberta Empreendedora (EDE) é um evento que reúne atores relevantes do ecossistema regional de inovação para impulsionar oportunidades no âmbito da Plataforma de Tecnologias Estratégicas para a Europa (STEP). Na sessão de 27 de novembro, o evento teve como propósito acelerar oportunidades STEP e consolidar a implementação do Programa Regional Lisboa 2030.',
#   'source': 'lisboa2030'},
#  {'question': 'Quais foram as atualizações principais do Aviso MPr-2025-14 republicado?',
#   'answer': 'As atualizações principais do Aviso MPr-2025-14 incluem: o prazo para início do investimento, que passa a ser de 90 dias após a apresentação da candidatura; esclarecimentos sobre a transferência do incentivo para empresas nos projetos do PT 2020; e a necessidade de comprovar quem realizou deslocações e a data em que ocorreram.',
#   'source': 'lisboa2030'},
#  {'question': 'Quais são os temas debatidos durante o encontro do EDE?',
#   'answer': 'Durante o encontro do EDE, foram debatidos temas como: fundos europeus e o enquadramento do PT 2030, investimentos em curso, reprogramação e prioridades estratégicas, oportunidades futuras com um calendário indicativo de avisos, e networking para troca de contactos e exploração de parcerias.',
#   'source': 'lisboa2030'},
#  {'question': 'Qual foi a mensagem da Presidente da CCDR LVT durante o evento EDE?',
#   'answer': 'A Presidente da CCDR LVT, Arquiteta Teresa Almeida, destacou a relevância do encontro EDE na reafirmação da região de Lisboa como um polo estratégico de inovação e competitividade, enfatizando a importância do alinhamento entre entidades públicas, empresas e centros de investigação para fortalecer o ecossistema regional de inovação.',
#   'source': 'lisboa2030'},
#  {'question': 'O que é o Portugal 2030?',
#   'answer': 'O Portugal 2030 é um programa que implementa o Acordo de Parceria entre Portugal e a Comissão Europeia, com o objetivo de aplicar 23 mil milhões de euros dos fundos europeus em projetos que estimulem e desenvolvam a economia portuguesa entre 2021 e 2027.',
#   'source': 'portugal2030'},
#  {'question': 'Quantos beneficiários já receberam pagamentos do Portugal 2030?',
#   'answer': 'Os pagamentos aos beneficiários do Portugal 2030 já ultrapassam os 3,3 mil milhões de euros, representando 30,4% do fundo aprovado.',
#   'source': 'portugal2030'},
#  {'question': 'Quais são os principais eventos relacionados ao Portugal 2030?',
#   'answer': 'Um dos principais eventos é a Mostra dos Fundos Europeus, onde são apresentados projetos e iniciativas apoiadas pelos fundos. Na última edição, foram anunciados os vencedores dos Prémios dos Fundos Europeus.',
#   'source': 'portugal2030'},
#  {'question': 'Como posso obter apoio técnico sobre o Balcão dos Fundos?',
#   'answer': 'O apoio técnico sobre o Balcão dos Fundos pode ser obtido através da Linha dos Fundos, que está disponível todos os dias úteis entre as 9h e as 18h, pelo telefone 800 10 35 10 (gratuito em Portugal) ou 00351 300 00 39 87 (custo de chamada para a rede fixa de Portugal).',
#   'source': 'portugal2030'},
#  {'question': 'O que é o projeto CustomNiTi?',
#   'answer': 'O projeto CustomNiTi, apoiado pelo Programa COMPETE 2030, está revolucionando o setor de dispositivos médicos ao desenvolver placas e distratores ósseos personalizados, visando melhorar a eficiência e o conforto no tratamento de fraturas ósseas.',
#   'source': 'portugal2030'}]

# %%
# ---------------- Embedding Helper ----------------
def get_embedding(text: str):
    """
    Returns embedding using your OpenAI client
    """
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return np.array(response.data[0].embedding, dtype=np.float32).reshape(1, -1)

# ---------------- Core Metrics ----------------
def f1_score(pred, ref):
    if not pred: return 0.0
    pred_tokens = pred.split()
    ref_tokens = ref.split()
    common = Counter(pred_tokens) & Counter(ref_tokens)
    num_same = sum(common.values())
    if num_same == 0: return 0.0
    precision = num_same / len(pred_tokens)
    recall = num_same / len(ref_tokens)
    return 2 * precision * recall / (precision + recall)

def conciseness_score(generated, reference):
    return len(reference.split()) / max(1, len(generated.split()))

def semantic_similarity_score(generated, references):
    """
    Computes max semantic similarity between generated answer and reference answers
    """
    gen_emb = get_embedding(generated)
    ref_embs = np.vstack([get_embedding(ref) for ref in references])
    sims = cosine_similarity(gen_emb, ref_embs)[0]
    return float(np.max(sims))


# ---------------- Embedding-based Retrieval Success ----------------
def retrieval_success_semantic(retrieved_docs, reference):
    """
    Returns the maximum semantic similarity between the reference and retrieved docs.
    If no docs are retrieved, returns 0.0.
    """
    if not retrieved_docs:
        return 0.0

    ref_emb = get_embedding(reference)
    max_sim = 0.0

    for doc in retrieved_docs:
        doc_text = doc.get("content", "").strip()
        if not doc_text:
            continue
        doc_emb = get_embedding(doc_text)
        sim = cosine_similarity(ref_emb, doc_emb)[0][0]
        if sim > max_sim:
            max_sim = sim

    return float(max_sim)


# ---------------- Embedding-based Grounding ----------------
def grounding_score_semantic(generated, retrieved_docs):
    """
    Fraction of generated answer semantically supported by retrieved docs
    """
    if not retrieved_docs:
        return 0.0

    gen_emb = get_embedding(generated)
    doc_embs = np.vstack([get_embedding(doc.get("content","")) for doc in retrieved_docs])
    sims = cosine_similarity(gen_emb, doc_embs)[0]
    return float(np.max(sims)) if len(sims) > 0 else 0.0

# %%
def evaluate_rag_semantic(dataset, index, metadata, bm25, 
                          k, model="gpt-4o-mini", use_rerank = False):
    results = []

    for item in dataset:
        question = item["question"]
        reference = item["answer"]
        source = item.get("source", "unknown")

        # Generate answer
        start_time = time.time()
        generated_answer, retrieved_docs = chatbot.answer(question, index, 
                                                          metadata, bm25,
                                                          k, model)
        latency = time.time() - start_time

        if isinstance(generated_answer, tuple):
            generated_answer = generated_answer[0]

        # Metrics
        retrieval_success = retrieval_success_semantic(retrieved_docs, reference)
        grounding = grounding_score_semantic(generated_answer, retrieved_docs)
        f1 = f1_score(generated_answer, reference)
        conciseness = conciseness_score(generated_answer, reference)
        semantic_sim = semantic_similarity_score(generated_answer, [reference])

        results.append({
            "Question": question,
            "Reference Answer": reference,
            "Source": source,
            "Generated Answer": generated_answer,
            "Retrieval Success (semantic)": retrieval_success,
            "Grounding (semantic)": grounding,
            "F1": f1,
            "Conciseness": conciseness,
            "Semantic Similarity": semantic_sim,
            "Latency (s)": latency
        })

    df = pd.DataFrame(results)
    return df

# %%
results = {}
for k in [10]:
    results[k] = evaluate_rag_semantic(documents, index, metadata, bm25, k=k)
# Out:
# Assistente: O Alentejo 2030 é um programa regional aprovado pela Comissão Europeia para o período de 2021-2027, que visa promover a inovação, a sustentabilidade e o crescimento da região do Alentejo. Através deste programa, a região dispõe de uma dotação global de fundos europeus, com o objetivo de transformar vidas e contribuir para o desenvolvimento local. O Alentejo 2030 apoia diversas áreas e projetos que visam melhorar a qualidade de vida dos cidadãos e impulsionar a economia da região.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: O documento menciona um evento que celebra projetos transformadores em Portugal, incluindo iniciativas do Alentejo 2030. Este evento é descrito como um ponto de encontro dinâmico, onde ocorrem debates, apresentações e momentos de partilha, além da cerimónia de entrega dos Prémios dos Fundos Europeus, que reconhecem projetos que estão a transformar a região.
#
# No entanto, não são especificados outros eventos programados. Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente

#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: O programa COMPETE 2030 apoia as empresas de várias maneiras, incluindo:
#
# 1. **Financiamento**: Oferece apoio financeiro para projetos de internacionalização, inovação e desenvolvimento tecnológico, permitindo que as empresas invistam em novas oportunidades.
#
# 2. **Concursos e Avisos**: Disponibiliza diversos avisos abertos que abrangem áreas como a internacionalização e a investigação e desenvolvimento (I&D), proporcionando oportunidades específicas para diferentes setores económicos.
#
# 3. **Promoção da Competitividade**: Ajuda as empresas a aumentar a sua competitividade global, através de investimentos em promoção externa e modernização.
#
# 4. **Apoio à Sustentabilidade**: Incentiva práticas sustentáveis que contribuem para a resiliência e sustentabilidade das empresas no mercado.
#
# Essas iniciativas visam fortalecer o tecido empresarial nacional e garantir que as empresas estejam bem posicionadas para enfrentar os desafios do mercado global.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: O canal +Transparente é um canal seguro que permite a submissão de denúncias à organização responsável pelo programa COMPETE 2030. Este canal pode ser utilizado por qualquer pessoa, mesmo que não tenha uma relação direta com a organização, para reportar irregularidades que necessitem de análise. As denúncias podem ser feitas de forma anónima ou identificada, e a informação será analisada de forma objetiva, imparcial e confidencial.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: A apresentação da Rede de Fornecedores Inovadores ocorrerá no dia 8 de maio de 2025. Esta sessão será coorganizada pelo Ministério da Economia, o COMPETE 2030 e os Programas Regionais do Portugal 2030.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: O StartUP Visa é um programa de acolhimento de empreendedores estrangeiros que desejam desenvolver um projeto de empreendedorismo e/ou inovação em Portugal. O objetivo do programa é facilitar a concessão de visto de residência ou autorização de residência para imigrantes empreendedores, permitindo que estes possam estabelecer e desenvolver as suas atividades no país.
#
# O StartUP Visa é regulado por um despacho normativo e envolve a certificação de incubadoras que estão aptas a acolher cidadãos de Estados terceiros, assegurando que estes têm o suporte necessário para o desenvolvimento dos seus projetos.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: Os principais serviços oferecidos pelo IAPMEI incluem:
#
# 1. **Apoio Técnico e Financeiro**: Assistência às empresas e empreendedores em áreas como inovação, internacionalização e desenvolvimento de negócios.
#
# 2. **Informação e Consultoria**: Disponibilização de informações sobre apoios e oportunidades de investimento, bem como consultoria personalizada.
#
# 3. **Centros de Apoio Empresarial**: Serviços prestados através dos Centros de Apoio Empresarial do IAPMEI, que oferecem suporte local às empresas.
#
# 4. **Parcerias e Produtos**: Colaboração com diversas entidades para disponibilizar produtos e serviços em condições favoráveis.
#
# 5. **Promoção de Iniciativas**: Organização de iniciativas que facilitem o acesso à informação e ao apoio a PME.
#
# Esses serviços visam fortalecer a competitividade e a sustentabilidade das empresas em Portugal.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: As empresas podem obter a certificação PME seguindo os seguintes passos:
#
# 1. **Registo Eletrónico**: A certificação deve ser antecedida de um registo eletrónico da empresa na plataforma adequada.
#
# 2. **Cumprimento dos Critérios**: As empresas devem cumprir os critérios estabelecidos para serem classificadas como micro, pequenas ou médias empresas, conforme definido pela legislação em vigor.
#
# 3. **Submissão de Documentação**: É necessário submeter a documentação requerida para a certificação, que pode incluir informações financeiras e operacionais da empresa.
#
# 4. **Avaliação**: A entidade responsável irá avaliar a documentação e verificar se a empresa cumpre os requisitos para a certificação.
#
# 5. **Obtenção do Comprovativo**: Após a aprovação, a empresa receberá um comprovativo do seu estatuto de PME Certificado.
#
# Para mais informações detalhadas, é aconselhável consultar a área específica do IAPMEI dedicada à certificação PME.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente:

#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: Os pagamentos aos beneficiários do Portugal 2030 já ultrapassaram os 3,3 mil milhões de euros. No entanto, o número exato de beneficiários que receberam esses pagamentos não foi especificado nas informações disponíveis.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: Os principais eventos relacionados ao Portugal 2030 incluem:
#
# 1. **Workshops e Seminários** - Focados em temas como inovação, sustentabilidade e desenvolvimento regional.
# 2. **Conferências** - Que reúnem especialistas e stakeholders para discutir as prioridades e os avanços do programa.
# 3. **Sessões de Informação** - Destinadas a esclarecer dúvidas sobre os programas e avisos do Portugal 2030.
#
# Esses eventos visam promover a troca de conhecimentos e a colaboração entre os diversos intervenientes do ecossistema.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: Para obter apoio técnico sobre o Balcão dos Fundos, você pode utilizar os seguintes canais:
#
# 1. **Email**: Envie suas questões para linhadosfundos@linhadosfundos.pt.
# 2. **Chat**: Acesse o chat disponível no site do Balcão dos Fundos, onde pode obter apoio ao registo e informações técnicas.
# 3. **Videochamada**: É possível agendar uma videochamada para receber apoio ao registo no Balcão dos Fundos.
# 4. **Telefone**: Ligue para o número 800 10 35 10 (gratuito para chamadas de Portugal) ou 00351 300 00 39 87 (para chamadas do estrangeiro).
#
# O suporte está disponível todos os dias úteis, entre as 9h e as 18h.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!
#
# Assistente: O projeto CustomNiTi é uma iniciativa inovadora que visa melhorar o tratamento de fraturas ósseas através do desenvolvimento de dispositivos médicos personalizados, como placas e distratores ósseos. Este projeto, cofinanciado pelo Programa COMPETE 2030, tem como objetivo aumentar a eficiência e o conforto no tratamento de fraturas, representando um avanço significativo na área da ortopedia. A CustomNiTi destaca-se como um exemplo de como a inovação pode transformar a medicina moderna e beneficiar os pacientes.
#
# Se precisar de mais informações ou ajuda sobre outro tema, estou à disposição!

# %%
results[10].describe()
# Out:
#        Retrieval Success (semantic)  Grounding (semantic)         F1  \
# count                     35.000000             35.000000  35.000000
# mean                       0.781298              0.813081   0.365315
# std                        0.131120              0.056584   0.146581
# min                        0.422468              0.710226   0.085470
# 25%                        0.699726              0.770324   0.260572
# 50%                        0.795816              0.817795   0.351145
# 75%                        0.888576              0.843168   0.454515
# max                        0.979310              0.926311   0.683544
#
#        Conciseness  Semantic Similarity  Latency (s)
# count    35.000000            35.000000    35.000000
# mean      0.473169             0.804216     2.139452
# std       0.176682             0.105822     0.486182
# min       0.223776             0.522829     1.459662
# 25%       0.326811             0.771621     1.770565
# 50%       0.455696             0.831597     2.064620
# 75%       0.600672             0.880902     2.407853
# max       0.880000             0.934519     3.729602

# %%
results[10][results[10]['F1'] < 0.3]
# Out:
#                                              Question  \
# 1   Quais são alguns dos eventos programados para ...
# 3   Quais são algumas das novas prioridades introd...
# 4   Como a reprogramação do Alentejo 2030 impacta ...
# 6   Quais são algumas das iniciativas relacionadas...
# 9   Quais são as áreas de investimento previstas n...
# 13  Como o Programa Centro 2030 combate a fraude n...
# 14  Quais são algumas das áreas de apoio incluídas...
# 16  Quais são os três pilares principais do progra...
# 17    Como o programa COMPETE 2030 apoia as empresas?
# 21  Quais são os principais serviços oferecidos pe...
# 22   Como as empresas podem obter a certificação PME?
# 24                         O que é a Academia de PME?
# 27  Quais foram as atualizações principais do Avis...
# 28  Quais são os temas debatidos durante o encontr...
# 32  Quais são os principais eventos relacionados a...
#
#                                      Reference Answer        Source  \
# 1   Alguns dos eventos programados incluem um work...  alentejo2030
# 3   As novas prioridades incluem a Defesa, a Água,...  alentejo2030
# 4   A reprogramação introduz maior flexibilidade n...  alentejo2030
# 6   As iniciativas incluem a redução de perdas nas...   algarve2030
# 9   As áreas de investimento incluem o aumento da ...   algarve2030
# 13  O Programa Centro 2030 combate a fraude nos fu...    centro2030
# 14  As áreas de apoio incluídas na reprogramação d...    centro2030
# 16  Os três pilares principais do programa COMPETE...   compete2030
# 17  O programa COMPETE 2030 apoia as empresas atra...   compete2030
# 21  Os principais serviços oferecidos pelo IAPMEI ...        iapmei
# 22  As empresas que desejam obter a certificação c...        iapmei
# 24  A Academia de PME é uma iniciativa do IAPMEI q...        iapmei
# 27  As atualizações principais do Aviso MPr-2025-1...    lisboa2030
# 28  Durante o encontro do EDE, foram debatidos tem...    lisboa2030
# 32  Um dos principais eventos é a Mostra dos Fundo...  portugal2030
#
#                                      Generated Answer  \
# 1   O documento menciona um evento que celebra pro...
# 3   Algumas das novas prioridades introduzidas pel...
# 4   A reprogramação do Alentejo 2030 impacta o apo...
# 6   Algumas das iniciativas relacionadas ao ciclo ...
# 9   As áreas de investimento previstas no Programa...
# 13  O Programa Centro 2030 combate a fraude nos fu...
# 14  Algumas das áreas de apoio incluídas na reprog...
# 16  Os três pilares principais do programa COMPETE...
# 17  O programa COMPETE 2030 apoia as empresas de v...
# 21  Os principais serviços oferecidos pelo IAPMEI ...
# 22  As empresas podem obter a certificação PME seg...
# 24  A Academia de PME do IAPMEI é uma iniciativa q...
# 27  O Aviso MPr-2025-14, que foi republicado com n...
# 28  Durante o encontro do Espaço de Descoberta Emp...
# 32  Os principais eventos relacionados ao Portugal...
#
#     Retrieval Success (semantic)  Grounding (semantic)        F1  Conciseness  \
# 1                       0.616848              0.841494  0.216667     0.621622
# 3                       0.591603              0.828334  0.215686     0.500000
# 4                       0.660948              0.769996  0.205882     0.346535
# 6                       0.846018              0.748796  0.289157     0.307087
# 9                       0.585701              0.789700  0.265957     0.296552
# 13                      0.824841              0.813269  0.260870     0.286713
# 14                      0.643108              0.710226  0.271605     0.306452
# 16                      0.716496              0.735499  0.260274     0.489796
# 17                      0.765818              0.776242  0.256098     0.223881
# 21                      0.693468              0.770653  0.193548     0.250000
# 22                      0.803495              0.787201  0.217143     0.223776
# 24                      0.797164              0.838977  0.283582     0.300971
# 27                      0.619700              0.817795  0.204724     0.693333
# 28                      0.640991              0.721057  0.271845     0.688525
# 32                      0.422468              0.750217  0.085470     0.360465
#
#     Semantic Similarity  Latency (s)
# 1              0.591383     2.106038
# 3              0.665305     2.224858
# 4              0.642367     2.391629
# 6              0.759286     2.739043
# 9              0.666882     2.687753
# 13             0.859217     2.894196
# 14             0.769852     2.311711
# 16             0.810025     2.875857
# 17             0.822518     2.513299
# 21             0.801644     2.424076
# 22             0.777550     2.627192
# 24             0.877118     2.150782
# 27             0.636487     1.877179
# 28             0.634266     1.635310
# 32             0.522829     1.994882
